# %% [markdown]
# # Tutorial: GNNs for 2D Particle Tracking
#
# Marcin Wolter
# *Jul 2024*
#
# Based (very closely) on:
# HEP.TrkX group
# Steve Farrell, Daniel Murname
#
# *Feb 2020*

# %% [markdown]
# ## **What's new?**
#
# In this code we do not do a binary classification anymore, but we would like to classify "edges" as:
# * not belonging to any track (none),
# * belonging to the positively charged track,
# * belonging to the negatively charged track,
#
# so a mechanism like PID (Particle IDentification) is added.
#
# 1. Therefore we have to change the data structure, the edge weight (variable *y*) is no longer a scalar but a vector of three numbers denoting the probilities of the edge being a member of  given class (for eample *y=[0.1, 0.9, 0]* means that the edge is most probably a part of positively charged track.
#
# 2. The edge network has to have a vector of three numbers as an output:
#
# ```
#         # The edge classifier computes final edge scores
#         self.edge_classifier = make_mlp(2*hidden_node_dim,
#                                         [hidden_edge_dim, 3],
#                                         output_activation=None)
# ```
#
# 3. The loss function can not be `binary_cross_entropy_with_logits()` any longer and has to be replaced by `cross_entropy()`:
#
#         #loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
#         loss = F.cross_entropy(pred.float(), data.y.float())
#
#  4. In few other places the code has to be modified. I kept the old code as commented lines.

# %%
# System imports
import os
import sys
from pprint import pprint as pp
from time import time as tt

# External imports
import matplotlib.pyplot as plt
import matplotlib.colors
import numpy as np
import pandas as pd
import seaborn as sns
import torch

# %%
print("PyTorch version:",print(torch.__version__),", CUDA version:", torch.version.cuda)
# Out:
# 2.1.0+cu121
# PyTorch version: None , CUDA version: 12.1

# %%
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch.nn as nn
from torch_scatter import scatter_add
import torch.nn.functional as F

import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from IPython.display import clear_output
from IPython.display import HTML, display

# %matplotlib inline

# Get rid of RuntimeWarnings, gross
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# ## The Problem

# %% [markdown]
# ### Toy Data
# Please try both max_angle cuts!

# %%
# Circle parameters
num_layers = 10
height, width = 10, 10
min_curve, max_curve = 15, 50
noise = False
event_size_min, event_size_max = 4, 12 #I.E. The number of true particle tracks
# Please try both cuts!
#max_angle=(4/6)*np.pi
max_angle=(6/6)*np.pi
feature_scale = np.array([10,10])

# %%
# Some dumb circle calculations
def y1(x, r, a, sign):
    return sign*np.sqrt(r**2 - a**2) + np.sqrt(r**2 - (x-a)**2)
def y2(x, r, a, sign):
    return sign*np.sqrt(r**2 - a**2) - np.sqrt(r**2 - (x-a)**2)

# Generate random circle / helix parameters
def rand_pars(event_size_min, event_size_max, max_curve, min_curve):
    event_size = int(np.floor(np.random.random(1)*(event_size_max - event_size_min) + event_size_min))
    radii = np.random.random(event_size)*(max_curve - min_curve) + min_curve
    dirs = np.random.random(event_size)*(radii)*2 -radii
    sign_options = np.array([-1,1])
    signs = sign_options[np.rint(np.random.random(event_size)).astype(int)]
    return radii, dirs, signs, event_size

def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=value, max=max))

# Generate event data from random parameters
def gen_edge_class(event_size_min, event_size_max, curve_min, curve_max, height, num_layers, max_angle, feature_scale, iter, num_samples):
    
    """ Feed params into randomiser """
    while True:
        radii, dirs, signs, event_size = rand_pars(event_size_min, event_size_max, curve_max, curve_min)
        xys = []
        X = np.empty([4,1])
        x = np.arange(0 + height/num_layers,height + height/num_layers, height/num_layers)
        i = 0
        for r, d, s in zip(radii, dirs, signs):
            y1test = y1(x, r, d, s)
        #     print(y1test, x)
            y2test = y2(x, r, d, s)
            if -2.5 < y1test[0] < 2.5 and not any(np.isnan(y1test)):
                X = np.append(X, np.vstack((y1test, np.array([i]*len(y1test)), x, np.ones(x.shape)*s )), axis=1)
                i += 1
            if -2.5 < y2test[0] < 2.5 and not any(np.isnan(y2test)):
                X = np.append(X, np.vstack((y2test, np.array([i]*len(y2test)), x, np.ones(x.shape)*s )), axis=1)
                i += 1
        X = X[:,1:].T
        np.random.shuffle(X)

        e = np.array([[i,j] for layer in np.arange(num_layers-1) for i in np.argwhere(X[:,2] == layer+1) for j in np.argwhere(X[:,2] == (layer+2)) if (X[i, 0] - np.tan(max_angle/2) < X[j, 0] < X[i, 0] + np.tan(max_angle/2))]).T.squeeze()
        
        # This handles when no edges were constructed. In that case, the randomisation is a do-over
        try:
            y00 = np.array([int(i[1] == j[1])*i[3] for i,j in zip(X[e[0]], X[e[1]])])
            
            y11 = np.zeros(y00.shape)
            y22 = np.zeros(y00.shape)
            y33 = np.zeros(y00.shape)
            
            y11[y00 ==  0] = 1
            y22[y00 ==  1] = 1
            y33[y00 == -1] = 1
           
            y  = np.stack((y11, y22, y33))
            y = y.T
            break
        except:
            pass
    if iter is not None and num_samples is not None:
        out.update(progress(iter, num_samples))    
    
    X = np.array([X[:,2], X[:,0]]).T / feature_scale

    data = Data(x = torch.from_numpy(X).float(), edge_index = torch.from_numpy(e), y = torch.from_numpy(y), pid = torch.from_numpy(X[:,1]))
    return data

# %%
train_size, test_size = 1000, 1000
out = display(progress(0, train_size), display_id=True)
train_dataset = [gen_edge_class(event_size_min, event_size_max, max_curve, min_curve, height, num_layers, max_angle, feature_scale, i, train_size) for i in range(train_size)]
out = display(progress(0, test_size), display_id=True)
test_dataset = [gen_edge_class(event_size_min, event_size_max, max_curve, min_curve, height, num_layers, max_angle, feature_scale, i, test_size) for i in range(test_size)]
train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=True)
# Out:
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>

# %%
def plot_toy_graph(event):
    plt.figure(figsize=(10,5))
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    e = event.edge_index.numpy()
#     for i, j in zip(X[e[0]], X[e[1]]):
#         plt.plot([i[0], j[0]], [i[1], j[1]], c='b')
    #     print(i[0], i[2], j[0], j[2])
    plt.plot([x[e[0,:]], x[e[1,:]]], [y[e[0,:]], y[e[1,:]]], c='b')
    plt.scatter(x, y, c='k')
    #plt.ylim(-1,1)

# %%
for i in range(5):
    plot_toy_graph(test_dataset[i])

# %% [markdown]
# The complexity of the graph depends on the angle cut we put on it. Try increasing max_angle to, say, `(5/6)*np.pi` and the graph should be more busy. The limit is of course `(6/6)*np.pi = pi` where each node will look at the full angle of available possible nodes to form an edge with. While playing with this number, run the next cell to see the proportion of fake edges to true edges (fake/true) on the above graph. This value will be extremely useful later.

# %%
#print("Fake / True = ", (len(train_dataset[0].y) - train_dataset[0].y.sum().item()) / train_dataset[0].y.sum().item())

# %% [markdown]
# ## A Simple GNN

# %% [markdown]
# ### Message Passing GNN

# %% [markdown]
# We can write out the full GNN as a class `MPNN_Network`. One can see its behaviour as:
# 1. Encode (x,y) features as hidden features with an N-layer MLP called `node_encoder`
# 2. Concatenate these along each edge, and feed the concatenated features into another MLP called `edge_network`
# 3. Sum the output of `edge_classifier` at each node (that is, each node receives the sum of the "messages" of all connecting edges). This sum is fed into `node_network`
# 4. Add the hidden features to the previous iteration (this helps to preserve information between messages)
# 5. Repeat (2) --> (4) n_graph_iters times
# 6. After the message passing loop, pass the features of each edge through an output classifier network called `edge_classifier`

# %%
def make_mlp(input_size, sizes,
             hidden_activation='ReLU',
             output_activation='ReLU',
             layer_norm=False):
    """Construct an MLP with specified fully-connected layers."""
    hidden_activation = getattr(nn, hidden_activation)
    if output_activation is not None:
        output_activation = getattr(nn, output_activation)
    layers = []
    n_layers = len(sizes)
    sizes = [input_size] + sizes
    # Hidden layers
    for i in range(n_layers-1):
        layers.append(nn.Linear(sizes[i], sizes[i+1]))
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[i+1]))
        layers.append(hidden_activation())
    # Final layer
    layers.append(nn.Linear(sizes[-2], sizes[-1]))
    if output_activation is not None:
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[-1]))
        layers.append(output_activation())
    return nn.Sequential(*layers)

class MPNN_Network(nn.Module):
    """
    A message-passing graph network which takes a graph with:
    - bi-directional edges
    - node features, no edge features

    and applies the following modules:
    - a graph encoder (no message passing)
    - recurrent edge and node networks
    - an edge classifier
    """

    def __init__(self, input_dim, hidden_node_dim, hidden_edge_dim, in_layers, node_layers, edge_layers,
                 n_graph_iters=1, layer_norm=True):
        super(MPNN_Network, self).__init__()
        self.n_graph_iters = n_graph_iters

        # The node encoder transforms input node features to the hidden space
        self.node_encoder = make_mlp(input_dim, [hidden_node_dim]*in_layers)

        # The edge network computes new edge features from connected nodes
        self.edge_network = make_mlp(2*hidden_node_dim,
                                     [hidden_edge_dim]*edge_layers,
                                     layer_norm=layer_norm)

        # The node network computes new node features
        self.node_network = make_mlp(hidden_node_dim + hidden_edge_dim,
                                     [hidden_node_dim]*node_layers,
                                     layer_norm=layer_norm)

        # The edge classifier computes final edge scores
        self.edge_classifier = make_mlp(2*hidden_node_dim,
                                        [hidden_edge_dim, 3],
                                        output_activation=None)

    def forward(self, data):
        # Make every edge bi-directional
        send_idx = torch.cat([data.edge_index[0], data.edge_index[1]], dim=0)
        recv_idx = torch.cat([data.edge_index[1], data.edge_index[0]], dim=0)

        # Encode the graph features into the hidden space
        x = self.node_encoder(data.x)

        # Loop over graph iterations
        for i in range(self.n_graph_iters):

            # Previous hidden state
            x0 = x

            # Compute new edge features
            edge_inputs = torch.cat([x[send_idx], x[recv_idx]], dim=1)
            e = self.edge_network(edge_inputs)

            # Sum edge features coming into each node
            aggr_messages = scatter_add(e, recv_idx, dim=0, dim_size=x.shape[0])

            # Compute new node features
            node_inputs = torch.cat([x, aggr_messages], dim=1)
            x = self.node_network(node_inputs)

            # Residual connection
            x = x + x0

        # Compute final edge scores; use original edge directions only
        start_idx, end_idx = data.edge_index
        clf_inputs = torch.cat([x[start_idx], x[end_idx]], dim=1)
        
        
        return self.edge_classifier(clf_inputs).squeeze(-1)

# %% [markdown]
# Build a version of the model and print it out.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
m_configs = {"input_dim": 2, "hidden_node_dim": 64, "hidden_edge_dim": 64, "in_layers": 2, "node_layers": 4, "edge_layers": 4, "n_graph_iters": 1, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)
model
# Out:
# MPNN_Network(
#   (node_encoder): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#   )
#   (edge_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (node_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (edge_classifier): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Training on Toy Data

# %%
def train(model, train_loader, optimizer, weight):
    correct = 0
    total = 0
    total_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        data = batch.to(device)
        pred = model(data)

        #loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        #loss = F.binary_cross_entropy(torch.sigmoid(pred.float()), torch.sigmoid(data.y.float()), weight=torch.tensor([weight]*len(data.y)).cuda())        
        loss = F.cross_entropy(pred.float(), data.y.float())
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        #correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        correct += (pred.argmax(axis=1) == data.y.argmax(axis=1)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

def evaluate(model, test_loader, weight):
    correct = 0
    total = 0
    total_loss = 0
    for batch in test_loader:
        data = batch.to(device)
        pred = model(data)
        #loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        #loss = F.binary_cross_entropy(torch.sigmoid(pred.float()), torch.sigmoid(data.y.float()), weight=torch.tensor([weight]*len(data.y)).cuda())
        loss = F.cross_entropy(pred.float(), data.y.float())
        total_loss += loss.item()
        #correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        correct += (pred.argmax(axis=1) == data.y.argmax(axis=1)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

# %%
t_loss_v = []
t_acc_v = []
v_loss_v = []
v_acc_v = []
ep = 0

# %% [markdown]
# We set a weight value that is more or less the (fake / true) ratio found above. This forces the loss function to punish incorrectly classified true edges more severely. It rebalances the distribution as if there was a 1:1 true:fake ratio.

# %% [markdown]
# ### Important:
#
# try various numbers of epochs, to save time train with fewer epochs (let say 200)

# %% [markdown]
# ### Exercise
#
# You can use a static number of epochs, but to save time, you can also add a stop condition for the learning process.
#
# Try to implement stopping after 10 epochs without improvement in the accuracy.
#
# It is also a good practice to store the model, that returned the best values - usually it won't be the last one in the process of training.

# %%
# %%time

epochs = 1000
weight = 2

m_configs = {"input_dim": 2, "hidden_node_dim": 16, "hidden_edge_dim": 16, "in_layers": 1, "node_layers": 2, "edge_layers": 2, "n_graph_iters": 6, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0008, weight_decay=1e-3, amsgrad=True)

for epoch in range(epochs):
    ep += 1  
    model.train()
    acc, total_loss = train(model, train_loader, optimizer, weight)
    t_loss_v.append(total_loss)
    t_acc_v.append(acc)

    model.eval()
    v_acc, v_total_loss = evaluate(model, test_loader, weight)
    v_loss_v.append(v_total_loss)
    v_acc_v.append(v_acc)

    print('Epoch: {}, Train accuracy: {:.4f}, val accuracy: {:.4f}, train loss: {:.4f}, val loss: {:.4f}'.format(ep, acc, v_acc, total_loss, v_total_loss))
# Out:
# Epoch: 1, Train accuracy: 0.0738, val accuracy: 0.0740, train loss: 31.7846, val loss: 22.0141
# Epoch: 2, Train accuracy: 0.0738, val accuracy: 0.0739, train loss: 17.3286, val loss: 12.5406
# Epoch: 3, Train accuracy: 0.5296, val accuracy: 0.8518, train loss: 10.0159, val loss: 7.5768
# Epoch: 4, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 6.5290, val loss: 5.7000
# Epoch: 5, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.4722, val loss: 5.2843
# Epoch: 6, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2643, val loss: 5.2400
# Epoch: 7, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2552, val loss: 5.2397
# Epoch: 8, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2487, val loss: 5.2287
# Epoch: 9, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2423, val loss: 5.2286
# Epoch: 10, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2435, val loss: 5.2229
# Epoch: 11, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2392, val loss: 5.2214
# Epoch: 12, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2384, val loss: 5.2295
# Epoch: 13, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2392, val loss: 5.2212
# Epoch: 14, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2369, val loss: 5.2222
# Epoch: 15, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2334, val loss: 5.2182
# Epoch: 16, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2356, val loss: 5.2146
# Epoch: 17, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2334, val loss: 5.2133
# Epoch: 18, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2262, val loss: 5.2127
# Epoch: 19, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2270, val loss: 5.2128
# Epoch: 20, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2182, val loss: 5.2114
# Epoch: 21, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2217, val loss: 5.2044
# Epoch: 22, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2112, val loss: 5.2012
# Epoch: 23, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2082, val loss: 5.2077
# Epoch: 24, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2068, val loss: 5.1903
# Epoch: 25, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.2001, val loss: 5.1882
# Epoch: 26, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1926, val loss: 5.1869
# Epoch: 27, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1920, val loss: 5.1878
# Epoch: 28, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1895, val loss: 5.1783
# Epoch: 29, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1887, val loss: 5.1779
# Epoch: 30, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1816, val loss: 5.1729
# Epoch: 31, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1827, val loss: 5.1750
# Epoch: 32, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1796, val loss: 5.1748
# Epoch: 33, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1758, val loss: 5.1707
# Epoch: 34, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1837, val loss: 5.1678
# Epoch: 35, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1774, val loss: 5.1679
# Epoch: 36, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1698, val loss: 5.1646
# Epoch: 37, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1712, val loss: 5.1655
# Epoch: 38, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1727, val loss: 5.1649
# Epoch: 39, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1741, val loss: 5.1608
# Epoch: 40, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1767, val loss: 5.1619
# Epoch: 41, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1696, val loss: 5.1625
# Epoch: 42, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1701, val loss: 5.1655
# Epoch: 43, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1733, val loss: 5.1609
# Epoch: 44, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1673, val loss: 5.1661
# Epoch: 45, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1694, val loss: 5.1612
# Epoch: 46, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1680, val loss: 5.1677
# Epoch: 47, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1658, val loss: 5.1643
# Epoch: 48, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1661, val loss: 5.1612
# Epoch: 49, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1633, val loss: 5.1640
# Epoch: 50, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1629, val loss: 5.1639
# Epoch: 51, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1730, val loss: 5.1589
# Epoch: 52, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1657, val loss: 5.1575
# Epoch: 53, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1626, val loss: 5.1582
# Epoch: 54, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1678, val loss: 5.1570
# Epoch: 55, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1637, val loss: 5.1540
# Epoch: 56, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1669, val loss: 5.1560
# Epoch: 57, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1607, val loss: 5.1531
# Epoch: 58, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1616, val loss: 5.1559
# Epoch: 59, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1603, val loss: 5.1563
# Epoch: 60, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1608, val loss: 5.1535
# Epoch: 61, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1571, val loss: 5.1530
# Epoch: 62, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1631, val loss: 5.1548
# Epoch: 63, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1623, val loss: 5.1520
# Epoch: 64, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1693, val loss: 5.1489
# Epoch: 65, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1624, val loss: 5.1537
# Epoch: 66, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1562, val loss: 5.1522
# Epoch: 67, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1588, val loss: 5.1485
# Epoch: 68, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1643, val loss: 5.1536
# Epoch: 69, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1601, val loss: 5.1486
# Epoch: 70, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1533, val loss: 5.1459
# Epoch: 71, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1535, val loss: 5.1462
# Epoch: 72, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1533, val loss: 5.1429
# Epoch: 73, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1536, val loss: 5.1456
# Epoch: 74, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1543, val loss: 5.1422
# Epoch: 75, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1522, val loss: 5.1420
# Epoch: 76, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1476, val loss: 5.1377
# Epoch: 77, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1440, val loss: 5.1459
# Epoch: 78, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1433, val loss: 5.1344
# Epoch: 79, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1412, val loss: 5.1312
# Epoch: 80, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1341, val loss: 5.1240
# Epoch: 81, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1276, val loss: 5.1129
# Epoch: 82, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1209, val loss: 5.1006
# Epoch: 83, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.1032, val loss: 5.0795
# Epoch: 84, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.0867, val loss: 5.0564
# Epoch: 85, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.0587, val loss: 5.0200
# Epoch: 86, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 5.0075, val loss: 4.9756
# Epoch: 87, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 4.9437, val loss: 4.8820
# Epoch: 88, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 4.8530, val loss: 4.7952
# Epoch: 89, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 4.7524, val loss: 4.6866
# Epoch: 90, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 4.6454, val loss: 4.5716
# Epoch: 91, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 4.5440, val loss: 4.4857
# Epoch: 92, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 4.4713, val loss: 4.4136
# Epoch: 93, Train accuracy: 0.8511, val accuracy: 0.8518, train loss: 4.3829, val loss: 4.3215
# Epoch: 94, Train accuracy: 0.8512, val accuracy: 0.8518, train loss: 4.3010, val loss: 4.2471
# Epoch: 95, Train accuracy: 0.8512, val accuracy: 0.8518, train loss: 4.2174, val loss: 4.1737
# Epoch: 96, Train accuracy: 0.8512, val accuracy: 0.8518, train loss: 4.1439, val loss: 4.0881
# Epoch: 97, Train accuracy: 0.8512, val accuracy: 0.8518, train loss: 4.0610, val loss: 3.9942
# Epoch: 98, Train accuracy: 0.8512, val accuracy: 0.8518, train loss: 3.9453, val loss: 3.8510
# Epoch: 99, Train accuracy: 0.8512, val accuracy: 0.8518, train loss: 3.7837, val loss: 3.6695
# Epoch: 100, Train accuracy: 0.8512, val accuracy: 0.8520, train loss: 3.5806, val loss: 3.4515
# Epoch: 101, Train accuracy: 0.8513, val accuracy: 0.8521, train loss: 3.3730, val loss: 3.2468
# Epoch: 102, Train accuracy: 0.8519, val accuracy: 0.8543, train loss: 3.1752, val loss: 3.0682
# Epoch: 103, Train accuracy: 0.8554, val accuracy: 0.8612, train loss: 3.0142, val loss: 2.9459
# Epoch: 104, Train accuracy: 0.8614, val accuracy: 0.8637, train loss: 2.9051, val loss: 2.8390
# Epoch: 105, Train accuracy: 0.8652, val accuracy: 0.8672, train loss: 2.7799, val loss: 2.7109
# Epoch: 106, Train accuracy: 0.8683, val accuracy: 0.8694, train loss: 2.6737, val loss: 2.6186
# Epoch: 107, Train accuracy: 0.8727, val accuracy: 0.8760, train loss: 2.5744, val loss: 2.5417
# Epoch: 108, Train accuracy: 0.8774, val accuracy: 0.8803, train loss: 2.5142, val loss: 2.4778
# Epoch: 109, Train accuracy: 0.8823, val accuracy: 0.8859, train loss: 2.4434, val loss: 2.3897
# Epoch: 110, Train accuracy: 0.8869, val accuracy: 0.8897, train loss: 2.3667, val loss: 2.3288
# Epoch: 111, Train accuracy: 0.8907, val accuracy: 0.8928, train loss: 2.3073, val loss: 2.2748
# Epoch: 112, Train accuracy: 0.8929, val accuracy: 0.8965, train loss: 2.2703, val loss: 2.2388
# Epoch: 113, Train accuracy: 0.8953, val accuracy: 0.8969, train loss: 2.2279, val loss: 2.2205
# Epoch: 114, Train accuracy: 0.8973, val accuracy: 0.9002, train loss: 2.1875, val loss: 2.1498
# Epoch: 115, Train accuracy: 0.8988, val accuracy: 0.9004, train loss: 2.1503, val loss: 2.1443
# Epoch: 116, Train accuracy: 0.8991, val accuracy: 0.8968, train loss: 2.1533, val loss: 2.2242
# Epoch: 117, Train accuracy: 0.8990, val accuracy: 0.9036, train loss: 2.1470, val loss: 2.0757
# Epoch: 118, Train accuracy: 0.9025, val accuracy: 0.9032, train loss: 2.0784, val loss: 2.0691
# Epoch: 119, Train accuracy: 0.9036, val accuracy: 0.9034, train loss: 2.0634, val loss: 2.0925
# Epoch: 120, Train accuracy: 0.9035, val accuracy: 0.9052, train loss: 2.0428, val loss: 2.0104
# Epoch: 121, Train accuracy: 0.9058, val accuracy: 0.9070, train loss: 1.9964, val loss: 1.9803
# Epoch: 122, Train accuracy: 0.9078, val accuracy: 0.9092, train loss: 1.9666, val loss: 1.9532
# Epoch: 123, Train accuracy: 0.9090, val accuracy: 0.9095, train loss: 1.9471, val loss: 1.9600
# Epoch: 124, Train accuracy: 0.9089, val accuracy: 0.9090, train loss: 1.9402, val loss: 1.9360
# Epoch: 125, Train accuracy: 0.9087, val accuracy: 0.9065, train loss: 1.9526, val loss: 1.9664
# Epoch: 126, Train accuracy: 0.9103, val accuracy: 0.9109, train loss: 1.9302, val loss: 1.8887
# Epoch: 127, Train accuracy: 0.9121, val accuracy: 0.9130, train loss: 1.8796, val loss: 1.8556
# Epoch: 128, Train accuracy: 0.9131, val accuracy: 0.9130, train loss: 1.8631, val loss: 1.8444
# Epoch: 129, Train accuracy: 0.9133, val accuracy: 0.9139, train loss: 1.8535, val loss: 1.8305
# Epoch: 130, Train accuracy: 0.9145, val accuracy: 0.9149, train loss: 1.8374, val loss: 1.8094
# Epoch: 131, Train accuracy: 0.9161, val accuracy: 0.9168, train loss: 1.8160, val loss: 1.8096
# Epoch: 132, Train accuracy: 0.9165, val accuracy: 0.9175, train loss: 1.8013, val loss: 1.7772
# Epoch: 133, Train accuracy: 0.9185, val accuracy: 0.9188, train loss: 1.7790, val loss: 1.7676
# Epoch: 134, Train accuracy: 0.9190, val accuracy: 0.9183, train loss: 1.7627, val loss: 1.7563
# Epoch: 135, Train accuracy: 0.9182, val accuracy: 0.9205, train loss: 1.7815, val loss: 1.7405
# Epoch: 136, Train accuracy: 0.9193, val accuracy: 0.9200, train loss: 1.7670, val loss: 1.7550
# Epoch: 137, Train accuracy: 0.9201, val accuracy: 0.9191, train loss: 1.7495, val loss: 1.7371
# Epoch: 138, Train accuracy: 0.9211, val accuracy: 0.9230, train loss: 1.7257, val loss: 1.7023
# Epoch: 139, Train accuracy: 0.9224, val accuracy: 0.9218, train loss: 1.7106, val loss: 1.7095
# Epoch: 140, Train accuracy: 0.9231, val accuracy: 0.9239, train loss: 1.6967, val loss: 1.6818
# Epoch: 141, Train accuracy: 0.9238, val accuracy: 0.9227, train loss: 1.6796, val loss: 1.6811
# Epoch: 142, Train accuracy: 0.9238, val accuracy: 0.9245, train loss: 1.6872, val loss: 1.6682
# Epoch: 143, Train accuracy: 0.9249, val accuracy: 0.9249, train loss: 1.6623, val loss: 1.6608
# Epoch: 144, Train accuracy: 0.9254, val accuracy: 0.9254, train loss: 1.6516, val loss: 1.6413
# Epoch: 145, Train accuracy: 0.9258, val accuracy: 0.9256, train loss: 1.6445, val loss: 1.6338
# Epoch: 146, Train accuracy: 0.9265, val accuracy: 0.9268, train loss: 1.6308, val loss: 1.6279
# Epoch: 147, Train accuracy: 0.9270, val accuracy: 0.9281, train loss: 1.6312, val loss: 1.6150
# Epoch: 148, Train accuracy: 0.9274, val accuracy: 0.9259, train loss: 1.6220, val loss: 1.6286
# Epoch: 149, Train accuracy: 0.9277, val accuracy: 0.9273, train loss: 1.6209, val loss: 1.6138
# Epoch: 150, Train accuracy: 0.9282, val accuracy: 0.9275, train loss: 1.6121, val loss: 1.6146
# Epoch: 151, Train accuracy: 0.9288, val accuracy: 0.9289, train loss: 1.6061, val loss: 1.5921
# Epoch: 152, Train accuracy: 0.9296, val accuracy: 0.9287, train loss: 1.5919, val loss: 1.5929
# Epoch: 153, Train accuracy: 0.9292, val accuracy: 0.9309, train loss: 1.5891, val loss: 1.5710
# Epoch: 154, Train accuracy: 0.9309, val accuracy: 0.9304, train loss: 1.5705, val loss: 1.5653
# Epoch: 155, Train accuracy: 0.9303, val accuracy: 0.9308, train loss: 1.5772, val loss: 1.5744
# Epoch: 156, Train accuracy: 0.9306, val accuracy: 0.9302, train loss: 1.5784, val loss: 1.5989
# Epoch: 157, Train accuracy: 0.9298, val accuracy: 0.9310, train loss: 1.5923, val loss: 1.6064
# Epoch: 158, Train accuracy: 0.9314, val accuracy: 0.9311, train loss: 1.5665, val loss: 1.5498
# Epoch: 159, Train accuracy: 0.9332, val accuracy: 0.9333, train loss: 1.5326, val loss: 1.5210
# Epoch: 160, Train accuracy: 0.9338, val accuracy: 0.9348, train loss: 1.5169, val loss: 1.5052
# Epoch: 161, Train accuracy: 0.9342, val accuracy: 0.9338, train loss: 1.5121, val loss: 1.5070
# Epoch: 162, Train accuracy: 0.9353, val accuracy: 0.9349, train loss: 1.5049, val loss: 1.4979
# Epoch: 163, Train accuracy: 0.9355, val accuracy: 0.9358, train loss: 1.4943, val loss: 1.4864
# Epoch: 164, Train accuracy: 0.9365, val accuracy: 0.9367, train loss: 1.4936, val loss: 1.4805
# Epoch: 165, Train accuracy: 0.9367, val accuracy: 0.9375, train loss: 1.4893, val loss: 1.4685
# Epoch: 166, Train accuracy: 0.9367, val accuracy: 0.9351, train loss: 1.4763, val loss: 1.4761
# Epoch: 167, Train accuracy: 0.9372, val accuracy: 0.9379, train loss: 1.4699, val loss: 1.4562
# Epoch: 168, Train accuracy: 0.9377, val accuracy: 0.9384, train loss: 1.4688, val loss: 1.4562
# Epoch: 169, Train accuracy: 0.9394, val accuracy: 0.9376, train loss: 1.4503, val loss: 1.4492
# Epoch: 170, Train accuracy: 0.9392, val accuracy: 0.9404, train loss: 1.4420, val loss: 1.4263
# Epoch: 171, Train accuracy: 0.9399, val accuracy: 0.9410, train loss: 1.4319, val loss: 1.4217
# Epoch: 172, Train accuracy: 0.9399, val accuracy: 0.9416, train loss: 1.4304, val loss: 1.4211
# Epoch: 173, Train accuracy: 0.9414, val accuracy: 0.9428, train loss: 1.4195, val loss: 1.3987
# Epoch: 174, Train accuracy: 0.9421, val accuracy: 0.9407, train loss: 1.4106, val loss: 1.4172
# Epoch: 175, Train accuracy: 0.9395, val accuracy: 0.9424, train loss: 1.4387, val loss: 1.4029
# Epoch: 176, Train accuracy: 0.9407, val accuracy: 0.9447, train loss: 1.4266, val loss: 1.3896
# Epoch: 177, Train accuracy: 0.9434, val accuracy: 0.9437, train loss: 1.4022, val loss: 1.3946
# Epoch: 178, Train accuracy: 0.9437, val accuracy: 0.9449, train loss: 1.3830, val loss: 1.3733
# Epoch: 179, Train accuracy: 0.9426, val accuracy: 0.9459, train loss: 1.4014, val loss: 1.3698
# Epoch: 180, Train accuracy: 0.9435, val accuracy: 0.9460, train loss: 1.3804, val loss: 1.3683
# Epoch: 181, Train accuracy: 0.9450, val accuracy: 0.9461, train loss: 1.3713, val loss: 1.3528
# Epoch: 182, Train accuracy: 0.9456, val accuracy: 0.9458, train loss: 1.3587, val loss: 1.3426
# Epoch: 183, Train accuracy: 0.9473, val accuracy: 0.9436, train loss: 1.3436, val loss: 1.3612
# Epoch: 184, Train accuracy: 0.9450, val accuracy: 0.9458, train loss: 1.3614, val loss: 1.3465
# Epoch: 185, Train accuracy: 0.9471, val accuracy: 0.9485, train loss: 1.3369, val loss: 1.3267
# Epoch: 186, Train accuracy: 0.9478, val accuracy: 0.9491, train loss: 1.3282, val loss: 1.3200
# Epoch: 187, Train accuracy: 0.9484, val accuracy: 0.9495, train loss: 1.3207, val loss: 1.3132
# Epoch: 188, Train accuracy: 0.9475, val accuracy: 0.9478, train loss: 1.3275, val loss: 1.3210
# Epoch: 189, Train accuracy: 0.9462, val accuracy: 0.9413, train loss: 1.3422, val loss: 1.4346
# Epoch: 190, Train accuracy: 0.9409, val accuracy: 0.9472, train loss: 1.4460, val loss: 1.3471
# Epoch: 191, Train accuracy: 0.9432, val accuracy: 0.9428, train loss: 1.3798, val loss: 1.3790
# Epoch: 192, Train accuracy: 0.9470, val accuracy: 0.9508, train loss: 1.3414, val loss: 1.3165
# Epoch: 193, Train accuracy: 0.9507, val accuracy: 0.9509, train loss: 1.2986, val loss: 1.2881
# Epoch: 194, Train accuracy: 0.9512, val accuracy: 0.9495, train loss: 1.2873, val loss: 1.2881
# Epoch: 195, Train accuracy: 0.9514, val accuracy: 0.9514, train loss: 1.2774, val loss: 1.2800
# Epoch: 196, Train accuracy: 0.9507, val accuracy: 0.9518, train loss: 1.2931, val loss: 1.2689
# Epoch: 197, Train accuracy: 0.9505, val accuracy: 0.9523, train loss: 1.2849, val loss: 1.2717
# Epoch: 198, Train accuracy: 0.9529, val accuracy: 0.9528, train loss: 1.2618, val loss: 1.2476
# Epoch: 199, Train accuracy: 0.9533, val accuracy: 0.9523, train loss: 1.2519, val loss: 1.2422
# Epoch: 200, Train accuracy: 0.9530, val accuracy: 0.9544, train loss: 1.2505, val loss: 1.2359
# Epoch: 201, Train accuracy: 0.9529, val accuracy: 0.9536, train loss: 1.2550, val loss: 1.2391
# Epoch: 202, Train accuracy: 0.9532, val accuracy: 0.9560, train loss: 1.2470, val loss: 1.2223
# Epoch: 203, Train accuracy: 0.9526, val accuracy: 0.9535, train loss: 1.2690, val loss: 1.2478
# Epoch: 204, Train accuracy: 0.9537, val accuracy: 0.9545, train loss: 1.2407, val loss: 1.2426
# Epoch: 205, Train accuracy: 0.9551, val accuracy: 0.9515, train loss: 1.2290, val loss: 1.2438
# Epoch: 206, Train accuracy: 0.9540, val accuracy: 0.9521, train loss: 1.2398, val loss: 1.2405
# Epoch: 207, Train accuracy: 0.9529, val accuracy: 0.9505, train loss: 1.2443, val loss: 1.2637
# Epoch: 208, Train accuracy: 0.9536, val accuracy: 0.9575, train loss: 1.2403, val loss: 1.2103
# Epoch: 209, Train accuracy: 0.9533, val accuracy: 0.9521, train loss: 1.2451, val loss: 1.2491
# Epoch: 210, Train accuracy: 0.9541, val accuracy: 0.9567, train loss: 1.2241, val loss: 1.1998
# Epoch: 211, Train accuracy: 0.9570, val accuracy: 0.9579, train loss: 1.2013, val loss: 1.1951
# Epoch: 212, Train accuracy: 0.9571, val accuracy: 0.9561, train loss: 1.1879, val loss: 1.2006
# Epoch: 213, Train accuracy: 0.9579, val accuracy: 0.9569, train loss: 1.1836, val loss: 1.1779
# Epoch: 214, Train accuracy: 0.9591, val accuracy: 0.9582, train loss: 1.1688, val loss: 1.1725
# Epoch: 215, Train accuracy: 0.9587, val accuracy: 0.9572, train loss: 1.1715, val loss: 1.1736
# Epoch: 216, Train accuracy: 0.9582, val accuracy: 0.9596, train loss: 1.1722, val loss: 1.1629
# Epoch: 217, Train accuracy: 0.9583, val accuracy: 0.9586, train loss: 1.1670, val loss: 1.1516
# Epoch: 218, Train accuracy: 0.9587, val accuracy: 0.9588, train loss: 1.1637, val loss: 1.1649
# Epoch: 219, Train accuracy: 0.9598, val accuracy: 0.9582, train loss: 1.1518, val loss: 1.1407
# Epoch: 220, Train accuracy: 0.9607, val accuracy: 0.9610, train loss: 1.1391, val loss: 1.1399
# Epoch: 221, Train accuracy: 0.9597, val accuracy: 0.9594, train loss: 1.1471, val loss: 1.1427
# Epoch: 222, Train accuracy: 0.9581, val accuracy: 0.9531, train loss: 1.1595, val loss: 1.2392
# Epoch: 223, Train accuracy: 0.9581, val accuracy: 0.9610, train loss: 1.1654, val loss: 1.1209
# Epoch: 224, Train accuracy: 0.9618, val accuracy: 0.9589, train loss: 1.1236, val loss: 1.1174
# Epoch: 225, Train accuracy: 0.9603, val accuracy: 0.9615, train loss: 1.1252, val loss: 1.1238
# Epoch: 226, Train accuracy: 0.9611, val accuracy: 0.9620, train loss: 1.1178, val loss: 1.1063
# Epoch: 227, Train accuracy: 0.9622, val accuracy: 0.9626, train loss: 1.1074, val loss: 1.0989
# Epoch: 228, Train accuracy: 0.9625, val accuracy: 0.9588, train loss: 1.0956, val loss: 1.1246
# Epoch: 229, Train accuracy: 0.9604, val accuracy: 0.9607, train loss: 1.1187, val loss: 1.1241
# Epoch: 230, Train accuracy: 0.9596, val accuracy: 0.9628, train loss: 1.1299, val loss: 1.0977
# Epoch: 231, Train accuracy: 0.9624, val accuracy: 0.9644, train loss: 1.0930, val loss: 1.0752
# Epoch: 232, Train accuracy: 0.9636, val accuracy: 0.9626, train loss: 1.0777, val loss: 1.0788
# Epoch: 233, Train accuracy: 0.9618, val accuracy: 0.9634, train loss: 1.0996, val loss: 1.0863
# Epoch: 234, Train accuracy: 0.9603, val accuracy: 0.9498, train loss: 1.1199, val loss: 1.2715
# Epoch: 235, Train accuracy: 0.9596, val accuracy: 0.9628, train loss: 1.1253, val loss: 1.0802
# Epoch: 236, Train accuracy: 0.9619, val accuracy: 0.9618, train loss: 1.1011, val loss: 1.0779
# Epoch: 237, Train accuracy: 0.9636, val accuracy: 0.9650, train loss: 1.0690, val loss: 1.0658
# Epoch: 238, Train accuracy: 0.9642, val accuracy: 0.9649, train loss: 1.0558, val loss: 1.0491
# Epoch: 239, Train accuracy: 0.9647, val accuracy: 0.9644, train loss: 1.0499, val loss: 1.0483
# Epoch: 240, Train accuracy: 0.9628, val accuracy: 0.9631, train loss: 1.0722, val loss: 1.0613
# Epoch: 241, Train accuracy: 0.9601, val accuracy: 0.9654, train loss: 1.1069, val loss: 1.0515
# Epoch: 242, Train accuracy: 0.9608, val accuracy: 0.9649, train loss: 1.0962, val loss: 1.0533
# Epoch: 243, Train accuracy: 0.9631, val accuracy: 0.9655, train loss: 1.0644, val loss: 1.0353
# Epoch: 244, Train accuracy: 0.9650, val accuracy: 0.9659, train loss: 1.0382, val loss: 1.0269
# Epoch: 245, Train accuracy: 0.9660, val accuracy: 0.9664, train loss: 1.0250, val loss: 1.0240
# Epoch: 246, Train accuracy: 0.9652, val accuracy: 0.9650, train loss: 1.0285, val loss: 1.0226
# Epoch: 247, Train accuracy: 0.9652, val accuracy: 0.9651, train loss: 1.0205, val loss: 1.0321
# Epoch: 248, Train accuracy: 0.9645, val accuracy: 0.9662, train loss: 1.0355, val loss: 1.0084
# Epoch: 249, Train accuracy: 0.9666, val accuracy: 0.9662, train loss: 1.0061, val loss: 1.0067
# Epoch: 250, Train accuracy: 0.9645, val accuracy: 0.9650, train loss: 1.0311, val loss: 1.0236
# Epoch: 251, Train accuracy: 0.9644, val accuracy: 0.9565, train loss: 1.0268, val loss: 1.1325
# Epoch: 252, Train accuracy: 0.9581, val accuracy: 0.9536, train loss: 1.1347, val loss: 1.1753
# Epoch: 253, Train accuracy: 0.9585, val accuracy: 0.9562, train loss: 1.1202, val loss: 1.1514
# Epoch: 254, Train accuracy: 0.9611, val accuracy: 0.9661, train loss: 1.0741, val loss: 1.0242
# Epoch: 255, Train accuracy: 0.9651, val accuracy: 0.9663, train loss: 1.0215, val loss: 1.0038
# Epoch: 256, Train accuracy: 0.9660, val accuracy: 0.9677, train loss: 1.0031, val loss: 0.9844
# Epoch: 257, Train accuracy: 0.9668, val accuracy: 0.9677, train loss: 0.9889, val loss: 0.9846
# Epoch: 258, Train accuracy: 0.9668, val accuracy: 0.9671, train loss: 0.9921, val loss: 0.9995
# Epoch: 259, Train accuracy: 0.9664, val accuracy: 0.9669, train loss: 0.9860, val loss: 0.9800
# Epoch: 260, Train accuracy: 0.9659, val accuracy: 0.9612, train loss: 0.9990, val loss: 1.0641
# Epoch: 261, Train accuracy: 0.9649, val accuracy: 0.9659, train loss: 1.0056, val loss: 0.9914
# Epoch: 262, Train accuracy: 0.9649, val accuracy: 0.9680, train loss: 1.0068, val loss: 0.9645
# Epoch: 263, Train accuracy: 0.9675, val accuracy: 0.9669, train loss: 0.9686, val loss: 0.9760
# Epoch: 264, Train accuracy: 0.9674, val accuracy: 0.9679, train loss: 0.9672, val loss: 0.9730
# Epoch: 265, Train accuracy: 0.9677, val accuracy: 0.9666, train loss: 0.9634, val loss: 0.9646
# Epoch: 266, Train accuracy: 0.9672, val accuracy: 0.9684, train loss: 0.9642, val loss: 0.9518
# Epoch: 267, Train accuracy: 0.9682, val accuracy: 0.9681, train loss: 0.9479, val loss: 0.9494
# Epoch: 268, Train accuracy: 0.9685, val accuracy: 0.9683, train loss: 0.9455, val loss: 0.9412
# Epoch: 269, Train accuracy: 0.9678, val accuracy: 0.9688, train loss: 0.9457, val loss: 0.9363
# Epoch: 270, Train accuracy: 0.9675, val accuracy: 0.9693, train loss: 0.9504, val loss: 0.9341
# Epoch: 271, Train accuracy: 0.9680, val accuracy: 0.9685, train loss: 0.9463, val loss: 0.9371
# Epoch: 272, Train accuracy: 0.9683, val accuracy: 0.9695, train loss: 0.9398, val loss: 0.9313
# Epoch: 273, Train accuracy: 0.9688, val accuracy: 0.9686, train loss: 0.9334, val loss: 0.9296
# Epoch: 274, Train accuracy: 0.9689, val accuracy: 0.9699, train loss: 0.9242, val loss: 0.9175
# Epoch: 275, Train accuracy: 0.9688, val accuracy: 0.9640, train loss: 0.9248, val loss: 0.9927
# Epoch: 276, Train accuracy: 0.9674, val accuracy: 0.9691, train loss: 0.9441, val loss: 0.9136
# Epoch: 277, Train accuracy: 0.9684, val accuracy: 0.9696, train loss: 0.9281, val loss: 0.9150
# Epoch: 278, Train accuracy: 0.9694, val accuracy: 0.9704, train loss: 0.9135, val loss: 0.9039
# Epoch: 279, Train accuracy: 0.9693, val accuracy: 0.9694, train loss: 0.9153, val loss: 0.9134
# Epoch: 280, Train accuracy: 0.9655, val accuracy: 0.9577, train loss: 0.9732, val loss: 1.0830
# Epoch: 281, Train accuracy: 0.9643, val accuracy: 0.9630, train loss: 0.9875, val loss: 1.0043
# Epoch: 282, Train accuracy: 0.9658, val accuracy: 0.9673, train loss: 0.9637, val loss: 0.9494
# Epoch: 283, Train accuracy: 0.9685, val accuracy: 0.9696, train loss: 0.9240, val loss: 0.9010
# Epoch: 284, Train accuracy: 0.9702, val accuracy: 0.9692, train loss: 0.9010, val loss: 0.9105
# Epoch: 285, Train accuracy: 0.9686, val accuracy: 0.9688, train loss: 0.9139, val loss: 0.9140
# Epoch: 286, Train accuracy: 0.9696, val accuracy: 0.9692, train loss: 0.8960, val loss: 0.9048
# Epoch: 287, Train accuracy: 0.9695, val accuracy: 0.9702, train loss: 0.8946, val loss: 0.8966
# Epoch: 288, Train accuracy: 0.9693, val accuracy: 0.9694, train loss: 0.8995, val loss: 0.8919
# Epoch: 289, Train accuracy: 0.9692, val accuracy: 0.9700, train loss: 0.8990, val loss: 0.8915
# Epoch: 290, Train accuracy: 0.9700, val accuracy: 0.9695, train loss: 0.8852, val loss: 0.8885
# Epoch: 291, Train accuracy: 0.9690, val accuracy: 0.9698, train loss: 0.8957, val loss: 0.8950
# Epoch: 292, Train accuracy: 0.9690, val accuracy: 0.9708, train loss: 0.8964, val loss: 0.8905
# Epoch: 293, Train accuracy: 0.9704, val accuracy: 0.9703, train loss: 0.8748, val loss: 0.8753
# Epoch: 294, Train accuracy: 0.9695, val accuracy: 0.9707, train loss: 0.8827, val loss: 0.8789
# Epoch: 295, Train accuracy: 0.9695, val accuracy: 0.9681, train loss: 0.8857, val loss: 0.9041
# Epoch: 296, Train accuracy: 0.9683, val accuracy: 0.9713, train loss: 0.9052, val loss: 0.8609
# Epoch: 297, Train accuracy: 0.9672, val accuracy: 0.9625, train loss: 0.9235, val loss: 0.9863
# Epoch: 298, Train accuracy: 0.9657, val accuracy: 0.9588, train loss: 0.9456, val loss: 1.0808
# Epoch: 299, Train accuracy: 0.9637, val accuracy: 0.9671, train loss: 0.9822, val loss: 0.9303
# Epoch: 300, Train accuracy: 0.9624, val accuracy: 0.9629, train loss: 0.9999, val loss: 0.9786
# Epoch: 301, Train accuracy: 0.9656, val accuracy: 0.9665, train loss: 0.9461, val loss: 0.9285
# Epoch: 302, Train accuracy: 0.9670, val accuracy: 0.9673, train loss: 0.9162, val loss: 0.9144
# Epoch: 303, Train accuracy: 0.9657, val accuracy: 0.9653, train loss: 0.9432, val loss: 0.9495
# Epoch: 304, Train accuracy: 0.9686, val accuracy: 0.9700, train loss: 0.9011, val loss: 0.8700
# Epoch: 305, Train accuracy: 0.9703, val accuracy: 0.9715, train loss: 0.8623, val loss: 0.8560
# Epoch: 306, Train accuracy: 0.9706, val accuracy: 0.9711, train loss: 0.8589, val loss: 0.8578
# Epoch: 307, Train accuracy: 0.9712, val accuracy: 0.9710, train loss: 0.8494, val loss: 0.8461
# Epoch: 308, Train accuracy: 0.9711, val accuracy: 0.9716, train loss: 0.8489, val loss: 0.8419
# Epoch: 309, Train accuracy: 0.9708, val accuracy: 0.9715, train loss: 0.8487, val loss: 0.8466
# Epoch: 310, Train accuracy: 0.9712, val accuracy: 0.9711, train loss: 0.8402, val loss: 0.8400
# Epoch: 311, Train accuracy: 0.9715, val accuracy: 0.9719, train loss: 0.8362, val loss: 0.8319
# Epoch: 312, Train accuracy: 0.9711, val accuracy: 0.9722, train loss: 0.8367, val loss: 0.8341
# Epoch: 313, Train accuracy: 0.9700, val accuracy: 0.9703, train loss: 0.8561, val loss: 0.8531
# Epoch: 314, Train accuracy: 0.9708, val accuracy: 0.9723, train loss: 0.8430, val loss: 0.8327
# Epoch: 315, Train accuracy: 0.9701, val accuracy: 0.9709, train loss: 0.8534, val loss: 0.8506
# Epoch: 316, Train accuracy: 0.9712, val accuracy: 0.9715, train loss: 0.8377, val loss: 0.8322
# Epoch: 317, Train accuracy: 0.9712, val accuracy: 0.9719, train loss: 0.8312, val loss: 0.8208
# Epoch: 318, Train accuracy: 0.9707, val accuracy: 0.9710, train loss: 0.8379, val loss: 0.8359
# Epoch: 319, Train accuracy: 0.9700, val accuracy: 0.9683, train loss: 0.8448, val loss: 0.8741
# Epoch: 320, Train accuracy: 0.9708, val accuracy: 0.9723, train loss: 0.8395, val loss: 0.8151
# Epoch: 321, Train accuracy: 0.9715, val accuracy: 0.9707, train loss: 0.8238, val loss: 0.8317
# Epoch: 322, Train accuracy: 0.9713, val accuracy: 0.9722, train loss: 0.8240, val loss: 0.8117
# Epoch: 323, Train accuracy: 0.9711, val accuracy: 0.9721, train loss: 0.8263, val loss: 0.8136
# Epoch: 324, Train accuracy: 0.9716, val accuracy: 0.9729, train loss: 0.8152, val loss: 0.8098
# Epoch: 325, Train accuracy: 0.9719, val accuracy: 0.9721, train loss: 0.8121, val loss: 0.8059
# Epoch: 326, Train accuracy: 0.9720, val accuracy: 0.9721, train loss: 0.8074, val loss: 0.8087
# Epoch: 327, Train accuracy: 0.9719, val accuracy: 0.9707, train loss: 0.8089, val loss: 0.8313
# Epoch: 328, Train accuracy: 0.9707, val accuracy: 0.9680, train loss: 0.8310, val loss: 0.8652
# Epoch: 329, Train accuracy: 0.9711, val accuracy: 0.9714, train loss: 0.8226, val loss: 0.8112
# Epoch: 330, Train accuracy: 0.9723, val accuracy: 0.9712, train loss: 0.8029, val loss: 0.8079
# Epoch: 331, Train accuracy: 0.9719, val accuracy: 0.9722, train loss: 0.8035, val loss: 0.7999
# Epoch: 332, Train accuracy: 0.9723, val accuracy: 0.9729, train loss: 0.7964, val loss: 0.7893
# Epoch: 333, Train accuracy: 0.9723, val accuracy: 0.9725, train loss: 0.7935, val loss: 0.7923
# Epoch: 334, Train accuracy: 0.9723, val accuracy: 0.9712, train loss: 0.7931, val loss: 0.8248
# Epoch: 335, Train accuracy: 0.9724, val accuracy: 0.9727, train loss: 0.7941, val loss: 0.7816
# Epoch: 336, Train accuracy: 0.9727, val accuracy: 0.9723, train loss: 0.7904, val loss: 0.7830
# Epoch: 337, Train accuracy: 0.9718, val accuracy: 0.9728, train loss: 0.8007, val loss: 0.7877
# Epoch: 338, Train accuracy: 0.9706, val accuracy: 0.9727, train loss: 0.8149, val loss: 0.7967
# Epoch: 339, Train accuracy: 0.9634, val accuracy: 0.9572, train loss: 0.9740, val loss: 1.0930
# Epoch: 340, Train accuracy: 0.9613, val accuracy: 0.9625, train loss: 1.0140, val loss: 0.9658
# Epoch: 341, Train accuracy: 0.9654, val accuracy: 0.9661, train loss: 0.9011, val loss: 0.8858
# Epoch: 342, Train accuracy: 0.9692, val accuracy: 0.9733, train loss: 0.8457, val loss: 0.7955
# Epoch: 343, Train accuracy: 0.9718, val accuracy: 0.9728, train loss: 0.8036, val loss: 0.7867
# Epoch: 344, Train accuracy: 0.9728, val accuracy: 0.9728, train loss: 0.7840, val loss: 0.7786
# Epoch: 345, Train accuracy: 0.9724, val accuracy: 0.9726, train loss: 0.7860, val loss: 0.7887
# Epoch: 346, Train accuracy: 0.9725, val accuracy: 0.9727, train loss: 0.7875, val loss: 0.7822
# Epoch: 347, Train accuracy: 0.9723, val accuracy: 0.9728, train loss: 0.7860, val loss: 0.7787
# Epoch: 348, Train accuracy: 0.9723, val accuracy: 0.9720, train loss: 0.7843, val loss: 0.7910
# Epoch: 349, Train accuracy: 0.9725, val accuracy: 0.9731, train loss: 0.7755, val loss: 0.7719
# Epoch: 350, Train accuracy: 0.9729, val accuracy: 0.9726, train loss: 0.7700, val loss: 0.7736
# Epoch: 351, Train accuracy: 0.9730, val accuracy: 0.9721, train loss: 0.7681, val loss: 0.7753
# Epoch: 352, Train accuracy: 0.9730, val accuracy: 0.9731, train loss: 0.7692, val loss: 0.7648
# Epoch: 353, Train accuracy: 0.9727, val accuracy: 0.9729, train loss: 0.7723, val loss: 0.7650
# Epoch: 354, Train accuracy: 0.9731, val accuracy: 0.9727, train loss: 0.7626, val loss: 0.7698
# Epoch: 355, Train accuracy: 0.9731, val accuracy: 0.9732, train loss: 0.7645, val loss: 0.7572
# Epoch: 356, Train accuracy: 0.9730, val accuracy: 0.9727, train loss: 0.7613, val loss: 0.7680
# Epoch: 357, Train accuracy: 0.9727, val accuracy: 0.9729, train loss: 0.7664, val loss: 0.7651
# Epoch: 358, Train accuracy: 0.9731, val accuracy: 0.9733, train loss: 0.7591, val loss: 0.7608
# Epoch: 359, Train accuracy: 0.9736, val accuracy: 0.9732, train loss: 0.7517, val loss: 0.7522
# Epoch: 360, Train accuracy: 0.9732, val accuracy: 0.9733, train loss: 0.7517, val loss: 0.7459
# Epoch: 361, Train accuracy: 0.9721, val accuracy: 0.9725, train loss: 0.7685, val loss: 0.7687
# Epoch: 362, Train accuracy: 0.9725, val accuracy: 0.9711, train loss: 0.7615, val loss: 0.7873
# Epoch: 363, Train accuracy: 0.9716, val accuracy: 0.9705, train loss: 0.7816, val loss: 0.7981
# Epoch: 364, Train accuracy: 0.9722, val accuracy: 0.9712, train loss: 0.7674, val loss: 0.7818
# Epoch: 365, Train accuracy: 0.9732, val accuracy: 0.9732, train loss: 0.7546, val loss: 0.7497
# Epoch: 366, Train accuracy: 0.9735, val accuracy: 0.9726, train loss: 0.7469, val loss: 0.7610
# Epoch: 367, Train accuracy: 0.9722, val accuracy: 0.9734, train loss: 0.7629, val loss: 0.7437
# Epoch: 368, Train accuracy: 0.9724, val accuracy: 0.9720, train loss: 0.7630, val loss: 0.7690
# Epoch: 369, Train accuracy: 0.9730, val accuracy: 0.9711, train loss: 0.7509, val loss: 0.7790
# Epoch: 370, Train accuracy: 0.9714, val accuracy: 0.9704, train loss: 0.7759, val loss: 0.7980
# Epoch: 371, Train accuracy: 0.9721, val accuracy: 0.9730, train loss: 0.7741, val loss: 0.7474
# Epoch: 372, Train accuracy: 0.9728, val accuracy: 0.9735, train loss: 0.7549, val loss: 0.7401
# Epoch: 373, Train accuracy: 0.9730, val accuracy: 0.9725, train loss: 0.7475, val loss: 0.7529
# Epoch: 374, Train accuracy: 0.9733, val accuracy: 0.9737, train loss: 0.7419, val loss: 0.7362
# Epoch: 375, Train accuracy: 0.9737, val accuracy: 0.9734, train loss: 0.7339, val loss: 0.7410
# Epoch: 376, Train accuracy: 0.9739, val accuracy: 0.9736, train loss: 0.7325, val loss: 0.7323
# Epoch: 377, Train accuracy: 0.9737, val accuracy: 0.9737, train loss: 0.7316, val loss: 0.7343
# Epoch: 378, Train accuracy: 0.9735, val accuracy: 0.9730, train loss: 0.7312, val loss: 0.7424
# Epoch: 379, Train accuracy: 0.9728, val accuracy: 0.9743, train loss: 0.7436, val loss: 0.7274
# Epoch: 380, Train accuracy: 0.9737, val accuracy: 0.9742, train loss: 0.7266, val loss: 0.7209
# Epoch: 381, Train accuracy: 0.9735, val accuracy: 0.9712, train loss: 0.7322, val loss: 0.7666
# Epoch: 382, Train accuracy: 0.9726, val accuracy: 0.9730, train loss: 0.7475, val loss: 0.7368
# Epoch: 383, Train accuracy: 0.9736, val accuracy: 0.9740, train loss: 0.7288, val loss: 0.7221
# Epoch: 384, Train accuracy: 0.9739, val accuracy: 0.9742, train loss: 0.7223, val loss: 0.7217
# Epoch: 385, Train accuracy: 0.9737, val accuracy: 0.9739, train loss: 0.7251, val loss: 0.7197
# Epoch: 386, Train accuracy: 0.9732, val accuracy: 0.9721, train loss: 0.7294, val loss: 0.7451
# Epoch: 387, Train accuracy: 0.9727, val accuracy: 0.9723, train loss: 0.7405, val loss: 0.7618
# Epoch: 388, Train accuracy: 0.9732, val accuracy: 0.9742, train loss: 0.7382, val loss: 0.7198
# Epoch: 389, Train accuracy: 0.9737, val accuracy: 0.9732, train loss: 0.7207, val loss: 0.7278
# Epoch: 390, Train accuracy: 0.9734, val accuracy: 0.9735, train loss: 0.7257, val loss: 0.7243
# Epoch: 391, Train accuracy: 0.9724, val accuracy: 0.9705, train loss: 0.7399, val loss: 0.7876
# Epoch: 392, Train accuracy: 0.9715, val accuracy: 0.9713, train loss: 0.7618, val loss: 0.7586
# Epoch: 393, Train accuracy: 0.9714, val accuracy: 0.9733, train loss: 0.7597, val loss: 0.7263
# Epoch: 394, Train accuracy: 0.9736, val accuracy: 0.9744, train loss: 0.7204, val loss: 0.7157
# Epoch: 395, Train accuracy: 0.9738, val accuracy: 0.9733, train loss: 0.7151, val loss: 0.7308
# Epoch: 396, Train accuracy: 0.9732, val accuracy: 0.9742, train loss: 0.7238, val loss: 0.7075
# Epoch: 397, Train accuracy: 0.9742, val accuracy: 0.9737, train loss: 0.7082, val loss: 0.7169
# Epoch: 398, Train accuracy: 0.9736, val accuracy: 0.9745, train loss: 0.7171, val loss: 0.7069
# Epoch: 399, Train accuracy: 0.9735, val accuracy: 0.9701, train loss: 0.7157, val loss: 0.7870
# Epoch: 400, Train accuracy: 0.9718, val accuracy: 0.9706, train loss: 0.7480, val loss: 0.7676
# Epoch: 401, Train accuracy: 0.9730, val accuracy: 0.9743, train loss: 0.7278, val loss: 0.7036
# Epoch: 402, Train accuracy: 0.9739, val accuracy: 0.9743, train loss: 0.7089, val loss: 0.7015
# Epoch: 403, Train accuracy: 0.9743, val accuracy: 0.9722, train loss: 0.7045, val loss: 0.7308
# Epoch: 404, Train accuracy: 0.9735, val accuracy: 0.9743, train loss: 0.7154, val loss: 0.7069
# Epoch: 405, Train accuracy: 0.9731, val accuracy: 0.9700, train loss: 0.7262, val loss: 0.7805
# Epoch: 406, Train accuracy: 0.9722, val accuracy: 0.9735, train loss: 0.7371, val loss: 0.7048
# Epoch: 407, Train accuracy: 0.9737, val accuracy: 0.9733, train loss: 0.7101, val loss: 0.7247
# Epoch: 408, Train accuracy: 0.9726, val accuracy: 0.9686, train loss: 0.7265, val loss: 0.8019
# Epoch: 409, Train accuracy: 0.9711, val accuracy: 0.9708, train loss: 0.7606, val loss: 0.7603
# Epoch: 410, Train accuracy: 0.9730, val accuracy: 0.9745, train loss: 0.7246, val loss: 0.7000
# Epoch: 411, Train accuracy: 0.9739, val accuracy: 0.9741, train loss: 0.7080, val loss: 0.6992
# Epoch: 412, Train accuracy: 0.9733, val accuracy: 0.9736, train loss: 0.7101, val loss: 0.7127
# Epoch: 413, Train accuracy: 0.9741, val accuracy: 0.9744, train loss: 0.7008, val loss: 0.6971
# Epoch: 414, Train accuracy: 0.9745, val accuracy: 0.9748, train loss: 0.6938, val loss: 0.6890
# Epoch: 415, Train accuracy: 0.9743, val accuracy: 0.9738, train loss: 0.6962, val loss: 0.7098
# Epoch: 416, Train accuracy: 0.9734, val accuracy: 0.9653, train loss: 0.7158, val loss: 0.8806
# Epoch: 417, Train accuracy: 0.9711, val accuracy: 0.9731, train loss: 0.7576, val loss: 0.7180
# Epoch: 418, Train accuracy: 0.9745, val accuracy: 0.9748, train loss: 0.6953, val loss: 0.6895
# Epoch: 419, Train accuracy: 0.9747, val accuracy: 0.9742, train loss: 0.6853, val loss: 0.6882
# Epoch: 420, Train accuracy: 0.9739, val accuracy: 0.9742, train loss: 0.6941, val loss: 0.6969
# Epoch: 421, Train accuracy: 0.9744, val accuracy: 0.9741, train loss: 0.6931, val loss: 0.6879
# Epoch: 422, Train accuracy: 0.9746, val accuracy: 0.9748, train loss: 0.6873, val loss: 0.6856
# Epoch: 423, Train accuracy: 0.9744, val accuracy: 0.9745, train loss: 0.6843, val loss: 0.6901
# Epoch: 424, Train accuracy: 0.9745, val accuracy: 0.9745, train loss: 0.6859, val loss: 0.6855
# Epoch: 425, Train accuracy: 0.9737, val accuracy: 0.9735, train loss: 0.6955, val loss: 0.7005
# Epoch: 426, Train accuracy: 0.9730, val accuracy: 0.9743, train loss: 0.7123, val loss: 0.6894
# Epoch: 427, Train accuracy: 0.9740, val accuracy: 0.9737, train loss: 0.6925, val loss: 0.7061
# Epoch: 428, Train accuracy: 0.9726, val accuracy: 0.9737, train loss: 0.7179, val loss: 0.6996
# Epoch: 429, Train accuracy: 0.9739, val accuracy: 0.9738, train loss: 0.7001, val loss: 0.6927
# Epoch: 430, Train accuracy: 0.9727, val accuracy: 0.9726, train loss: 0.7241, val loss: 0.7241
# Epoch: 431, Train accuracy: 0.9733, val accuracy: 0.9743, train loss: 0.7083, val loss: 0.6963
# Epoch: 432, Train accuracy: 0.9743, val accuracy: 0.9744, train loss: 0.6867, val loss: 0.6834
# Epoch: 433, Train accuracy: 0.9746, val accuracy: 0.9751, train loss: 0.6801, val loss: 0.6718
# Epoch: 434, Train accuracy: 0.9744, val accuracy: 0.9748, train loss: 0.6794, val loss: 0.6780
# Epoch: 435, Train accuracy: 0.9748, val accuracy: 0.9740, train loss: 0.6729, val loss: 0.6798
# Epoch: 436, Train accuracy: 0.9747, val accuracy: 0.9753, train loss: 0.6759, val loss: 0.6668
# Epoch: 437, Train accuracy: 0.9744, val accuracy: 0.9744, train loss: 0.6772, val loss: 0.6734
# Epoch: 438, Train accuracy: 0.9745, val accuracy: 0.9751, train loss: 0.6773, val loss: 0.6680
# Epoch: 439, Train accuracy: 0.9746, val accuracy: 0.9734, train loss: 0.6738, val loss: 0.6971
# Epoch: 440, Train accuracy: 0.9732, val accuracy: 0.9745, train loss: 0.6995, val loss: 0.6769
# Epoch: 441, Train accuracy: 0.9728, val accuracy: 0.9739, train loss: 0.7075, val loss: 0.6854
# Epoch: 442, Train accuracy: 0.9734, val accuracy: 0.9746, train loss: 0.6959, val loss: 0.6804
# Epoch: 443, Train accuracy: 0.9744, val accuracy: 0.9747, train loss: 0.6771, val loss: 0.6790
# Epoch: 444, Train accuracy: 0.9742, val accuracy: 0.9744, train loss: 0.6815, val loss: 0.6759
# Epoch: 445, Train accuracy: 0.9747, val accuracy: 0.9750, train loss: 0.6702, val loss: 0.6627
# Epoch: 446, Train accuracy: 0.9746, val accuracy: 0.9751, train loss: 0.6734, val loss: 0.6684
# Epoch: 447, Train accuracy: 0.9750, val accuracy: 0.9750, train loss: 0.6673, val loss: 0.6710
# Epoch: 448, Train accuracy: 0.9746, val accuracy: 0.9748, train loss: 0.6708, val loss: 0.6717
# Epoch: 449, Train accuracy: 0.9750, val accuracy: 0.9746, train loss: 0.6639, val loss: 0.6699
# Epoch: 450, Train accuracy: 0.9746, val accuracy: 0.9753, train loss: 0.6645, val loss: 0.6577
# Epoch: 451, Train accuracy: 0.9748, val accuracy: 0.9750, train loss: 0.6640, val loss: 0.6631
# Epoch: 452, Train accuracy: 0.9752, val accuracy: 0.9747, train loss: 0.6596, val loss: 0.6685
# Epoch: 453, Train accuracy: 0.9745, val accuracy: 0.9736, train loss: 0.6706, val loss: 0.6872
# Epoch: 454, Train accuracy: 0.9734, val accuracy: 0.9722, train loss: 0.6879, val loss: 0.7127
# Epoch: 455, Train accuracy: 0.9743, val accuracy: 0.9745, train loss: 0.6792, val loss: 0.6701
# Epoch: 456, Train accuracy: 0.9742, val accuracy: 0.9698, train loss: 0.6755, val loss: 0.7598
# Epoch: 457, Train accuracy: 0.9727, val accuracy: 0.9694, train loss: 0.7028, val loss: 0.7620
# Epoch: 458, Train accuracy: 0.9663, val accuracy: 0.9632, train loss: 0.8492, val loss: 0.9324
# Epoch: 459, Train accuracy: 0.9703, val accuracy: 0.9744, train loss: 0.7658, val loss: 0.6834
# Epoch: 460, Train accuracy: 0.9742, val accuracy: 0.9750, train loss: 0.6809, val loss: 0.6652
# Epoch: 461, Train accuracy: 0.9750, val accuracy: 0.9754, train loss: 0.6593, val loss: 0.6611
# Epoch: 462, Train accuracy: 0.9753, val accuracy: 0.9747, train loss: 0.6553, val loss: 0.6617
# Epoch: 463, Train accuracy: 0.9749, val accuracy: 0.9755, train loss: 0.6574, val loss: 0.6521
# Epoch: 464, Train accuracy: 0.9750, val accuracy: 0.9746, train loss: 0.6561, val loss: 0.6588
# Epoch: 465, Train accuracy: 0.9751, val accuracy: 0.9754, train loss: 0.6557, val loss: 0.6485
# Epoch: 466, Train accuracy: 0.9748, val accuracy: 0.9748, train loss: 0.6585, val loss: 0.6725
# Epoch: 467, Train accuracy: 0.9738, val accuracy: 0.9754, train loss: 0.6762, val loss: 0.6509
# Epoch: 468, Train accuracy: 0.9724, val accuracy: 0.9708, train loss: 0.7009, val loss: 0.7406
# Epoch: 469, Train accuracy: 0.9742, val accuracy: 0.9750, train loss: 0.6727, val loss: 0.6557
# Epoch: 470, Train accuracy: 0.9748, val accuracy: 0.9753, train loss: 0.6590, val loss: 0.6482
# Epoch: 471, Train accuracy: 0.9749, val accuracy: 0.9742, train loss: 0.6603, val loss: 0.6663
# Epoch: 472, Train accuracy: 0.9748, val accuracy: 0.9748, train loss: 0.6558, val loss: 0.6573
# Epoch: 473, Train accuracy: 0.9753, val accuracy: 0.9746, train loss: 0.6483, val loss: 0.6699
# Epoch: 474, Train accuracy: 0.9749, val accuracy: 0.9754, train loss: 0.6524, val loss: 0.6464
# Epoch: 475, Train accuracy: 0.9753, val accuracy: 0.9749, train loss: 0.6499, val loss: 0.6489
# Epoch: 476, Train accuracy: 0.9752, val accuracy: 0.9756, train loss: 0.6459, val loss: 0.6413
# Epoch: 477, Train accuracy: 0.9753, val accuracy: 0.9756, train loss: 0.6446, val loss: 0.6401
# Epoch: 478, Train accuracy: 0.9754, val accuracy: 0.9757, train loss: 0.6421, val loss: 0.6382
# Epoch: 479, Train accuracy: 0.9750, val accuracy: 0.9751, train loss: 0.6498, val loss: 0.6517
# Epoch: 480, Train accuracy: 0.9747, val accuracy: 0.9730, train loss: 0.6550, val loss: 0.6849
# Epoch: 481, Train accuracy: 0.9733, val accuracy: 0.9749, train loss: 0.6808, val loss: 0.6509
# Epoch: 482, Train accuracy: 0.9745, val accuracy: 0.9743, train loss: 0.6605, val loss: 0.6767
# Epoch: 483, Train accuracy: 0.9743, val accuracy: 0.9759, train loss: 0.6685, val loss: 0.6395
# Epoch: 484, Train accuracy: 0.9752, val accuracy: 0.9756, train loss: 0.6435, val loss: 0.6426
# Epoch: 485, Train accuracy: 0.9752, val accuracy: 0.9752, train loss: 0.6471, val loss: 0.6426
# Epoch: 486, Train accuracy: 0.9755, val accuracy: 0.9756, train loss: 0.6358, val loss: 0.6344
# Epoch: 487, Train accuracy: 0.9752, val accuracy: 0.9757, train loss: 0.6401, val loss: 0.6359
# Epoch: 488, Train accuracy: 0.9755, val accuracy: 0.9755, train loss: 0.6408, val loss: 0.6383
# Epoch: 489, Train accuracy: 0.9749, val accuracy: 0.9749, train loss: 0.6463, val loss: 0.6617
# Epoch: 490, Train accuracy: 0.9752, val accuracy: 0.9754, train loss: 0.6424, val loss: 0.6394
# Epoch: 491, Train accuracy: 0.9754, val accuracy: 0.9754, train loss: 0.6359, val loss: 0.6323
# Epoch: 492, Train accuracy: 0.9755, val accuracy: 0.9755, train loss: 0.6340, val loss: 0.6339
# Epoch: 493, Train accuracy: 0.9754, val accuracy: 0.9757, train loss: 0.6356, val loss: 0.6330
# Epoch: 494, Train accuracy: 0.9751, val accuracy: 0.9756, train loss: 0.6404, val loss: 0.6319
# Epoch: 495, Train accuracy: 0.9754, val accuracy: 0.9758, train loss: 0.6342, val loss: 0.6361
# Epoch: 496, Train accuracy: 0.9753, val accuracy: 0.9755, train loss: 0.6350, val loss: 0.6313
# Epoch: 497, Train accuracy: 0.9753, val accuracy: 0.9748, train loss: 0.6345, val loss: 0.6462
# Epoch: 498, Train accuracy: 0.9732, val accuracy: 0.9719, train loss: 0.6759, val loss: 0.7000
# Epoch: 499, Train accuracy: 0.9698, val accuracy: 0.9690, train loss: 0.7727, val loss: 0.7693
# Epoch: 500, Train accuracy: 0.9724, val accuracy: 0.9745, train loss: 0.7068, val loss: 0.6700
# Epoch: 501, Train accuracy: 0.9748, val accuracy: 0.9755, train loss: 0.6531, val loss: 0.6356
# Epoch: 502, Train accuracy: 0.9752, val accuracy: 0.9751, train loss: 0.6432, val loss: 0.6381
# Epoch: 503, Train accuracy: 0.9753, val accuracy: 0.9753, train loss: 0.6349, val loss: 0.6357
# Epoch: 504, Train accuracy: 0.9750, val accuracy: 0.9737, train loss: 0.6430, val loss: 0.6615
# Epoch: 505, Train accuracy: 0.9746, val accuracy: 0.9758, train loss: 0.6475, val loss: 0.6257
# Epoch: 506, Train accuracy: 0.9754, val accuracy: 0.9756, train loss: 0.6321, val loss: 0.6316
# ...
# Epoch: 834, Train accuracy: 0.9772, val accuracy: 0.9773, train loss: 0.5412, val loss: 0.5404
# Epoch: 835, Train accuracy: 0.9771, val accuracy: 0.9770, train loss: 0.5420, val loss: 0.5428
# Epoch: 836, Train accuracy: 0.9762, val accuracy: 0.9750, train loss: 0.5652, val loss: 0.5961
# Epoch: 837, Train accuracy: 0.9765, val accuracy: 0.9771, train loss: 0.5646, val loss: 0.5464
# Epoch: 838, Train accuracy: 0.9770, val accuracy: 0.9775, train loss: 0.5466, val loss: 0.5491
# Epoch: 839, Train accuracy: 0.9772, val accuracy: 0.9774, train loss: 0.5418, val loss: 0.5404
# Epoch: 840, Train accuracy: 0.9772, val accuracy: 0.9771, train loss: 0.5410, val loss: 0.5459
# Epoch: 841, Train accuracy: 0.9771, val accuracy: 0.9774, train loss: 0.5420, val loss: 0.5396
# Epoch: 842, Train accuracy: 0.9769, val accuracy: 0.9772, train loss: 0.5458, val loss: 0.5448
# Epoch: 843, Train accuracy: 0.9770, val accuracy: 0.9771, train loss: 0.5451, val loss: 0.5411
# Epoch: 844, Train accuracy: 0.9771, val accuracy: 0.9771, train loss: 0.5415, val loss: 0.5421
# Epoch: 845, Train accuracy: 0.9771, val accuracy: 0.9773, train loss: 0.5414, val loss: 0.5458
# Epoch: 846, Train accuracy: 0.9772, val accuracy: 0.9762, train loss: 0.5411, val loss: 0.5606
# Epoch: 847, Train accuracy: 0.9769, val accuracy: 0.9769, train loss: 0.5472, val loss: 0.5482
# Epoch: 848, Train accuracy: 0.9765, val accuracy: 0.9769, train loss: 0.5590, val loss: 0.5484
# Epoch: 849, Train accuracy: 0.9768, val accuracy: 0.9776, train loss: 0.5474, val loss: 0.5462
# Epoch: 850, Train accuracy: 0.9772, val accuracy: 0.9775, train loss: 0.5416, val loss: 0.5448
# Epoch: 851, Train accuracy: 0.9769, val accuracy: 0.9772, train loss: 0.5481, val loss: 0.5418
# Epoch: 852, Train accuracy: 0.9767, val accuracy: 0.9774, train loss: 0.5489, val loss: 0.5426
# Epoch: 853, Train accuracy: 0.9774, val accuracy: 0.9774, train loss: 0.5394, val loss: 0.5370
# Epoch: 854, Train accuracy: 0.9772, val accuracy: 0.9773, train loss: 0.5406, val loss: 0.5418
# Epoch: 855, Train accuracy: 0.9772, val accuracy: 0.9770, train loss: 0.5392, val loss: 0.5465
# Epoch: 856, Train accuracy: 0.9765, val accuracy: 0.9757, train loss: 0.5497, val loss: 0.5738
# Epoch: 857, Train accuracy: 0.9769, val accuracy: 0.9767, train loss: 0.5474, val loss: 0.5498
# Epoch: 858, Train accuracy: 0.9769, val accuracy: 0.9766, train loss: 0.5409, val loss: 0.5481
# Epoch: 859, Train accuracy: 0.9766, val accuracy: 0.9762, train loss: 0.5490, val loss: 0.5677
# Epoch: 860, Train accuracy: 0.9766, val accuracy: 0.9765, train loss: 0.5537, val loss: 0.5531
# Epoch: 861, Train accuracy: 0.9772, val accuracy: 0.9769, train loss: 0.5408, val loss: 0.5442
# Epoch: 862, Train accuracy: 0.9772, val accuracy: 0.9769, train loss: 0.5377, val loss: 0.5470
# Epoch: 863, Train accuracy: 0.9770, val accuracy: 0.9766, train loss: 0.5439, val loss: 0.5552
# Epoch: 864, Train accuracy: 0.9764, val accuracy: 0.9773, train loss: 0.5572, val loss: 0.5450
# Epoch: 865, Train accuracy: 0.9759, val accuracy: 0.9743, train loss: 0.5654, val loss: 0.6060
# Epoch: 866, Train accuracy: 0.9723, val accuracy: 0.9705, train loss: 0.6633, val loss: 0.6833
# Epoch: 867, Train accuracy: 0.9741, val accuracy: 0.9718, train loss: 0.6120, val loss: 0.6650
# Epoch: 868, Train accuracy: 0.9735, val accuracy: 0.9753, train loss: 0.6254, val loss: 0.5942
# Epoch: 869, Train accuracy: 0.9763, val accuracy: 0.9771, train loss: 0.5636, val loss: 0.5459
# Epoch: 870, Train accuracy: 0.9770, val accuracy: 0.9774, train loss: 0.5483, val loss: 0.5403
# Epoch: 871, Train accuracy: 0.9774, val accuracy: 0.9770, train loss: 0.5399, val loss: 0.5454
# Epoch: 872, Train accuracy: 0.9773, val accuracy: 0.9773, train loss: 0.5383, val loss: 0.5442
# Epoch: 873, Train accuracy: 0.9772, val accuracy: 0.9772, train loss: 0.5418, val loss: 0.5410
# Epoch: 874, Train accuracy: 0.9771, val accuracy: 0.9772, train loss: 0.5412, val loss: 0.5370
# Epoch: 875, Train accuracy: 0.9772, val accuracy: 0.9775, train loss: 0.5396, val loss: 0.5349
# Epoch: 876, Train accuracy: 0.9773, val accuracy: 0.9772, train loss: 0.5363, val loss: 0.5379
# Epoch: 877, Train accuracy: 0.9771, val accuracy: 0.9764, train loss: 0.5383, val loss: 0.5570
# Epoch: 878, Train accuracy: 0.9769, val accuracy: 0.9772, train loss: 0.5449, val loss: 0.5423
# Epoch: 879, Train accuracy: 0.9769, val accuracy: 0.9772, train loss: 0.5472, val loss: 0.5426
# Epoch: 880, Train accuracy: 0.9771, val accuracy: 0.9774, train loss: 0.5421, val loss: 0.5381
# Epoch: 881, Train accuracy: 0.9774, val accuracy: 0.9773, train loss: 0.5367, val loss: 0.5344
# Epoch: 882, Train accuracy: 0.9774, val accuracy: 0.9771, train loss: 0.5388, val loss: 0.5386
# Epoch: 883, Train accuracy: 0.9772, val accuracy: 0.9771, train loss: 0.5383, val loss: 0.5412
# Epoch: 884, Train accuracy: 0.9772, val accuracy: 0.9775, train loss: 0.5369, val loss: 0.5345
# Epoch: 885, Train accuracy: 0.9774, val accuracy: 0.9772, train loss: 0.5342, val loss: 0.5410
# Epoch: 886, Train accuracy: 0.9774, val accuracy: 0.9777, train loss: 0.5355, val loss: 0.5340
# Epoch: 887, Train accuracy: 0.9774, val accuracy: 0.9772, train loss: 0.5339, val loss: 0.5379
# Epoch: 888, Train accuracy: 0.9773, val accuracy: 0.9774, train loss: 0.5367, val loss: 0.5332
# Epoch: 889, Train accuracy: 0.9773, val accuracy: 0.9771, train loss: 0.5346, val loss: 0.5423
# Epoch: 890, Train accuracy: 0.9769, val accuracy: 0.9767, train loss: 0.5409, val loss: 0.5552
# Epoch: 891, Train accuracy: 0.9765, val accuracy: 0.9769, train loss: 0.5528, val loss: 0.5415
# Epoch: 892, Train accuracy: 0.9769, val accuracy: 0.9771, train loss: 0.5430, val loss: 0.5465
# Epoch: 893, Train accuracy: 0.9774, val accuracy: 0.9774, train loss: 0.5363, val loss: 0.5384
# Epoch: 894, Train accuracy: 0.9775, val accuracy: 0.9775, train loss: 0.5334, val loss: 0.5350
# Epoch: 895, Train accuracy: 0.9773, val accuracy: 0.9773, train loss: 0.5358, val loss: 0.5357
# Epoch: 896, Train accuracy: 0.9769, val accuracy: 0.9772, train loss: 0.5432, val loss: 0.5405
# Epoch: 897, Train accuracy: 0.9773, val accuracy: 0.9771, train loss: 0.5360, val loss: 0.5372
# Epoch: 898, Train accuracy: 0.9774, val accuracy: 0.9770, train loss: 0.5324, val loss: 0.5401
# Epoch: 899, Train accuracy: 0.9773, val accuracy: 0.9769, train loss: 0.5360, val loss: 0.5417
# Epoch: 900, Train accuracy: 0.9773, val accuracy: 0.9769, train loss: 0.5361, val loss: 0.5439
# Epoch: 901, Train accuracy: 0.9773, val accuracy: 0.9769, train loss: 0.5382, val loss: 0.5477
# Epoch: 902, Train accuracy: 0.9772, val accuracy: 0.9772, train loss: 0.5377, val loss: 0.5347
# Epoch: 903, Train accuracy: 0.9773, val accuracy: 0.9775, train loss: 0.5331, val loss: 0.5366
# Epoch: 904, Train accuracy: 0.9773, val accuracy: 0.9771, train loss: 0.5331, val loss: 0.5371
# Epoch: 905, Train accuracy: 0.9773, val accuracy: 0.9775, train loss: 0.5336, val loss: 0.5344
# Epoch: 906, Train accuracy: 0.9767, val accuracy: 0.9751, train loss: 0.5449, val loss: 0.5842
# Epoch: 907, Train accuracy: 0.9761, val accuracy: 0.9744, train loss: 0.5608, val loss: 0.6077
# Epoch: 908, Train accuracy: 0.9761, val accuracy: 0.9775, train loss: 0.5636, val loss: 0.5373
# Epoch: 909, Train accuracy: 0.9772, val accuracy: 0.9766, train loss: 0.5388, val loss: 0.5491
# Epoch: 910, Train accuracy: 0.9769, val accuracy: 0.9775, train loss: 0.5469, val loss: 0.5377
# Epoch: 911, Train accuracy: 0.9771, val accuracy: 0.9763, train loss: 0.5356, val loss: 0.5549
# Epoch: 912, Train accuracy: 0.9769, val accuracy: 0.9777, train loss: 0.5417, val loss: 0.5306
# Epoch: 913, Train accuracy: 0.9770, val accuracy: 0.9763, train loss: 0.5426, val loss: 0.5618
# Epoch: 914, Train accuracy: 0.9711, val accuracy: 0.9751, train loss: 0.7150, val loss: 0.6139
# Epoch: 915, Train accuracy: 0.9693, val accuracy: 0.9737, train loss: 0.7439, val loss: 0.6217
# Epoch: 916, Train accuracy: 0.9706, val accuracy: 0.9691, train loss: 0.6950, val loss: 0.7321
# Epoch: 917, Train accuracy: 0.9693, val accuracy: 0.9765, train loss: 0.7308, val loss: 0.5816
# Epoch: 918, Train accuracy: 0.9737, val accuracy: 0.9761, train loss: 0.6292, val loss: 0.5774
# Epoch: 919, Train accuracy: 0.9763, val accuracy: 0.9771, train loss: 0.5679, val loss: 0.5516
# Epoch: 920, Train accuracy: 0.9772, val accuracy: 0.9771, train loss: 0.5450, val loss: 0.5407
# Epoch: 921, Train accuracy: 0.9774, val accuracy: 0.9776, train loss: 0.5387, val loss: 0.5351
# Epoch: 922, Train accuracy: 0.9775, val accuracy: 0.9774, train loss: 0.5336, val loss: 0.5390
# Epoch: 923, Train accuracy: 0.9773, val accuracy: 0.9772, train loss: 0.5389, val loss: 0.5453
# Epoch: 924, Train accuracy: 0.9770, val accuracy: 0.9767, train loss: 0.5436, val loss: 0.5482
# Epoch: 925, Train accuracy: 0.9769, val accuracy: 0.9772, train loss: 0.5402, val loss: 0.5381
# Epoch: 926, Train accuracy: 0.9773, val accuracy: 0.9774, train loss: 0.5335, val loss: 0.5370
# Epoch: 927, Train accuracy: 0.9774, val accuracy: 0.9772, train loss: 0.5327, val loss: 0.5354
# Epoch: 928, Train accuracy: 0.9776, val accuracy: 0.9778, train loss: 0.5314, val loss: 0.5315
# Epoch: 929, Train accuracy: 0.9774, val accuracy: 0.9778, train loss: 0.5302, val loss: 0.5272
# Epoch: 930, Train accuracy: 0.9775, val accuracy: 0.9775, train loss: 0.5289, val loss: 0.5312
# Epoch: 931, Train accuracy: 0.9774, val accuracy: 0.9777, train loss: 0.5301, val loss: 0.5290
# Epoch: 932, Train accuracy: 0.9775, val accuracy: 0.9775, train loss: 0.5317, val loss: 0.5293
# Epoch: 933, Train accuracy: 0.9776, val accuracy: 0.9777, train loss: 0.5268, val loss: 0.5288
# Epoch: 934, Train accuracy: 0.9777, val accuracy: 0.9774, train loss: 0.5278, val loss: 0.5352
# Epoch: 935, Train accuracy: 0.9777, val accuracy: 0.9777, train loss: 0.5287, val loss: 0.5265
# Epoch: 936, Train accuracy: 0.9776, val accuracy: 0.9776, train loss: 0.5282, val loss: 0.5300
# Epoch: 937, Train accuracy: 0.9773, val accuracy: 0.9772, train loss: 0.5354, val loss: 0.5364
# Epoch: 938, Train accuracy: 0.9774, val accuracy: 0.9774, train loss: 0.5356, val loss: 0.5337
# Epoch: 939, Train accuracy: 0.9774, val accuracy: 0.9776, train loss: 0.5310, val loss: 0.5286
# Epoch: 940, Train accuracy: 0.9776, val accuracy: 0.9778, train loss: 0.5270, val loss: 0.5304
# Epoch: 941, Train accuracy: 0.9775, val accuracy: 0.9775, train loss: 0.5315, val loss: 0.5275
# Epoch: 942, Train accuracy: 0.9775, val accuracy: 0.9777, train loss: 0.5271, val loss: 0.5311
# Epoch: 943, Train accuracy: 0.9775, val accuracy: 0.9769, train loss: 0.5272, val loss: 0.5455
# Epoch: 944, Train accuracy: 0.9770, val accuracy: 0.9771, train loss: 0.5357, val loss: 0.5409
# Epoch: 945, Train accuracy: 0.9773, val accuracy: 0.9774, train loss: 0.5296, val loss: 0.5330
# Epoch: 946, Train accuracy: 0.9775, val accuracy: 0.9773, train loss: 0.5274, val loss: 0.5343
# Epoch: 947, Train accuracy: 0.9771, val accuracy: 0.9769, train loss: 0.5356, val loss: 0.5460
# Epoch: 948, Train accuracy: 0.9772, val accuracy: 0.9777, train loss: 0.5338, val loss: 0.5284
# Epoch: 949, Train accuracy: 0.9776, val accuracy: 0.9775, train loss: 0.5275, val loss: 0.5302
# Epoch: 950, Train accuracy: 0.9773, val accuracy: 0.9776, train loss: 0.5309, val loss: 0.5298
# Epoch: 951, Train accuracy: 0.9772, val accuracy: 0.9773, train loss: 0.5330, val loss: 0.5291
# Epoch: 952, Train accuracy: 0.9775, val accuracy: 0.9776, train loss: 0.5270, val loss: 0.5266
# Epoch: 953, Train accuracy: 0.9772, val accuracy: 0.9771, train loss: 0.5327, val loss: 0.5368
# Epoch: 954, Train accuracy: 0.9771, val accuracy: 0.9772, train loss: 0.5371, val loss: 0.5357
# Epoch: 955, Train accuracy: 0.9772, val accuracy: 0.9776, train loss: 0.5332, val loss: 0.5279
# Epoch: 956, Train accuracy: 0.9776, val accuracy: 0.9772, train loss: 0.5255, val loss: 0.5370
# Epoch: 957, Train accuracy: 0.9775, val accuracy: 0.9773, train loss: 0.5291, val loss: 0.5287
# Epoch: 958, Train accuracy: 0.9772, val accuracy: 0.9773, train loss: 0.5315, val loss: 0.5385
# Epoch: 959, Train accuracy: 0.9771, val accuracy: 0.9773, train loss: 0.5346, val loss: 0.5348
# Epoch: 960, Train accuracy: 0.9769, val accuracy: 0.9775, train loss: 0.5344, val loss: 0.5276
# Epoch: 961, Train accuracy: 0.9775, val accuracy: 0.9775, train loss: 0.5271, val loss: 0.5267
# Epoch: 962, Train accuracy: 0.9771, val accuracy: 0.9780, train loss: 0.5350, val loss: 0.5297
# Epoch: 963, Train accuracy: 0.9770, val accuracy: 0.9773, train loss: 0.5375, val loss: 0.5367
# Epoch: 964, Train accuracy: 0.9773, val accuracy: 0.9775, train loss: 0.5328, val loss: 0.5330
# Epoch: 965, Train accuracy: 0.9775, val accuracy: 0.9767, train loss: 0.5317, val loss: 0.5500
# Epoch: 966, Train accuracy: 0.9771, val accuracy: 0.9761, train loss: 0.5377, val loss: 0.5539
# Epoch: 967, Train accuracy: 0.9767, val accuracy: 0.9769, train loss: 0.5489, val loss: 0.5445
# Epoch: 968, Train accuracy: 0.9773, val accuracy: 0.9776, train loss: 0.5313, val loss: 0.5253
# Epoch: 969, Train accuracy: 0.9775, val accuracy: 0.9778, train loss: 0.5252, val loss: 0.5266
# Epoch: 970, Train accuracy: 0.9772, val accuracy: 0.9775, train loss: 0.5313, val loss: 0.5310
# Epoch: 971, Train accuracy: 0.9774, val accuracy: 0.9774, train loss: 0.5279, val loss: 0.5363
# Epoch: 972, Train accuracy: 0.9771, val accuracy: 0.9768, train loss: 0.5339, val loss: 0.5455
# Epoch: 973, Train accuracy: 0.9771, val accuracy: 0.9773, train loss: 0.5368, val loss: 0.5302
# Epoch: 974, Train accuracy: 0.9771, val accuracy: 0.9757, train loss: 0.5380, val loss: 0.5676
# Epoch: 975, Train accuracy: 0.9771, val accuracy: 0.9767, train loss: 0.5383, val loss: 0.5411
# Epoch: 976, Train accuracy: 0.9773, val accuracy: 0.9778, train loss: 0.5332, val loss: 0.5354
# Epoch: 977, Train accuracy: 0.9775, val accuracy: 0.9779, train loss: 0.5276, val loss: 0.5250
# Epoch: 978, Train accuracy: 0.9776, val accuracy: 0.9769, train loss: 0.5274, val loss: 0.5367
# Epoch: 979, Train accuracy: 0.9772, val accuracy: 0.9773, train loss: 0.5320, val loss: 0.5305
# Epoch: 980, Train accuracy: 0.9767, val accuracy: 0.9774, train loss: 0.5430, val loss: 0.5308
# Epoch: 981, Train accuracy: 0.9768, val accuracy: 0.9744, train loss: 0.5409, val loss: 0.5944
# Epoch: 982, Train accuracy: 0.9747, val accuracy: 0.9755, train loss: 0.5881, val loss: 0.5776
# Epoch: 983, Train accuracy: 0.9758, val accuracy: 0.9750, train loss: 0.5638, val loss: 0.5732
# Epoch: 984, Train accuracy: 0.9761, val accuracy: 0.9776, train loss: 0.5530, val loss: 0.5316
# Epoch: 985, Train accuracy: 0.9769, val accuracy: 0.9774, train loss: 0.5430, val loss: 0.5335
# Epoch: 986, Train accuracy: 0.9776, val accuracy: 0.9775, train loss: 0.5241, val loss: 0.5252
# Epoch: 987, Train accuracy: 0.9776, val accuracy: 0.9777, train loss: 0.5264, val loss: 0.5263
# Epoch: 988, Train accuracy: 0.9774, val accuracy: 0.9759, train loss: 0.5276, val loss: 0.5579
# Epoch: 989, Train accuracy: 0.9770, val accuracy: 0.9773, train loss: 0.5356, val loss: 0.5309
# Epoch: 990, Train accuracy: 0.9776, val accuracy: 0.9774, train loss: 0.5254, val loss: 0.5352
# Epoch: 991, Train accuracy: 0.9763, val accuracy: 0.9746, train loss: 0.5496, val loss: 0.5946
# Epoch: 992, Train accuracy: 0.9732, val accuracy: 0.9685, train loss: 0.6355, val loss: 0.7598
# Epoch: 993, Train accuracy: 0.9703, val accuracy: 0.9769, train loss: 0.7132, val loss: 0.5654
# Epoch: 994, Train accuracy: 0.9750, val accuracy: 0.9762, train loss: 0.5965, val loss: 0.5579
# Epoch: 995, Train accuracy: 0.9770, val accuracy: 0.9776, train loss: 0.5451, val loss: 0.5388
# Epoch: 996, Train accuracy: 0.9774, val accuracy: 0.9773, train loss: 0.5341, val loss: 0.5318
# Epoch: 997, Train accuracy: 0.9777, val accuracy: 0.9773, train loss: 0.5287, val loss: 0.5322
# Epoch: 998, Train accuracy: 0.9774, val accuracy: 0.9775, train loss: 0.5300, val loss: 0.5309
# Epoch: 999, Train accuracy: 0.9774, val accuracy: 0.9777, train loss: 0.5305, val loss: 0.5286
# Epoch: 1000, Train accuracy: 0.9772, val accuracy: 0.9775, train loss: 0.5297, val loss: 0.5354
# CPU times: user 4min 2s, sys: 290 ms, total: 4min 2s
# Wall time: 4min 2s

# %%
fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(10, 5))
axs[0].plot(np.arange(len(t_loss_v)), t_loss_v, label="training")
axs[0].plot(np.arange(len(v_loss_v)), v_loss_v, label="validation")
axs[0].set_title("Training and validation loss")
axs[0].set_yscale("log")
axs[0].legend()
axs[1].plot(np.arange(len(t_acc_v)), t_acc_v, label="training")
axs[1].plot(np.arange(len(v_acc_v)), v_acc_v, label="validation")
axs[1].set_title("Training and validation accuracy")
axs[1].set_yscale("linear")
axs[1].legend()
axs[1].set_ylim([0.90, np.max(t_acc_v)+0.001])
# Out:
# (0.9, 0.9786640026640027)

# %% [markdown]
# ### Did it work?

# %% [markdown]
# The best performance that I can get with some simple manual tuning is around 98% accuracy (for max_angle = 6/6*np.pi). We can improve the efficiency at the cost of purity by raising the weight on true edges, but the accuracy won't significantly improve. In general, the biggest changes were from increasing the width (i.e. the number of dimensions) of the hidden layers. We can visualise the performance on a particular graph, colouring true positives black, false positives red, true negatives a transparent black, and false negatives in blue.

# %%
def plot_toy_classified(event, preds, cut=0.5):
    
    plt.figure(figsize=(10,5))
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    edges = event.edge_index.numpy()
    labels = event.y
    plt.scatter(x, y, c='k')
    
    preds = preds.detach().numpy()
    
    for j in range(len(labels)):
        
        # False negatives
        #if preds[j,0] < cut and labels[j,0].item() > cut:
        if preds.argmax(axis=1)[j] == 0 and labels.argmax(axis=1)[j] > 0:    
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '--', c='b')

        # False positives
        #if preds[j,0] > cut and labels[j,0].item() < cut:
        if preds.argmax(axis=1)[j] > 0 and labels.argmax(axis=1)[j] == 0:    
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='r', alpha=preds[j,0])

        # True positives
        if preds.argmax(axis=1)[j] == 1 and labels.argmax(axis=1)[j] == 1:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='green', alpha=preds[j,1])
        if preds.argmax(axis=1)[j] == 2 and labels.argmax(axis=1)[j] == 2:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='orange', alpha=preds[j,2])
            
        # True negatives
        if preds.argmax(axis=1)[j] == 0 and labels.argmax(axis=1)[j] == 0:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='k', alpha=1-preds[j,0])

# %%
for i in range(5):
    data = test_loader.dataset[i].to(device)
    preds = torch.sigmoid(model(data)).to('cpu')
    plot_toy_classified(data.to('cpu'), preds, cut = 0.6)

# %% [markdown]
# So we can see that it's working quite well. Few missed true edges, and few misclassified fake edges. The ratio of false positives to false negatives (which can be defined with efficiency and purity) is controlled by the cut we put on the prediction score.

# %% [markdown]
# ### Plot the confussion matrix (for edges)

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
#from sklearn.metrics import RocCurveDisplay, roc_curve
#from sklearn.metrics import PrecisionRecallDisplay, precision_recall_curve

y_test = torch.cat([data.y.cpu().argmax(axis=1) for data in test_loader.dataset])
y_pred = torch.cat([torch.sigmoid(model(data.to(device))).argmax(axis=1) for data in test_loader.dataset]).cpu()

display_labels = ['none','pos','neg']
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=display_labels).plot()

# %% [markdown]
# # **That's all**
