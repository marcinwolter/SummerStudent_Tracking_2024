# %% [markdown]
# # Tutorial: GNNs for 2D Particle Tracking
#
# Marcin Wolter
# *Jul 2024*
#
# Based (very closely) on:
# HEP.TrkX group
# Steve Farrell, Daniel Murname
#
# *Feb 2020*

# %%
# System imports
import os
import sys
from pprint import pprint as pp
from time import time as tt

# External imports
import matplotlib.pyplot as plt
import matplotlib.colors
import numpy as np
import pandas as pd
import seaborn as sns
import torch

# %%
print("PyTorch version:",print(torch.__version__),", CUDA version:", torch.version.cuda)
# Out:
# 2.1.0a0
# PyTorch version: None , CUDA version: 11.8

# %%
#To be checked on another machine

# !pip install torch-geometric \
#   torch-sparse \
#   torch-scatter \
#   -f https://pytorch-geometric.com/whl/torch-1.11.0+cu113.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0+cu113.html
# Requirement already satisfied: torch-geometric in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: torch-sparse in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (0.6.17)
# Requirement already satisfied: torch-scatter in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (2.1.1)
# Requirement already satisfied: tqdm in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (4.66.1)
# Requirement already satisfied: numpy in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (1.23.5)
# Requirement already satisfied: scipy in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (1.11.3)
# Requirement already satisfied: jinja2 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: requests in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (2.4.7)
# Requirement already satisfied: scikit-learn in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from torch-geometric) (5.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from jinja2->torch-geometric) (2.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from requests->torch-geometric) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from requests->torch-geometric) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from requests->torch-geometric) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from requests->torch-geometric) (2022.12.7)
# Requirement already satisfied: joblib>=1.1.1 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from scikit-learn->torch-geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages (from scikit-learn->torch-geometric) (2.2.0)
# DEPRECATION: gosam 2.1.1-4b98559 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gosam or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: professor2 X.Y.Z has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of professor2 or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from torch_geometric.data import Data
from torch_geometric.data import DataLoader
import torch.nn as nn
from torch_scatter import scatter_add
import torch.nn.functional as F

import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from IPython.display import clear_output
from IPython.display import HTML, display

# %matplotlib inline

# Get rid of RuntimeWarnings, gross
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# ## The Problem

# %% [markdown]
# ### Toy Data
# Please try both max_angle cuts!

# %%
# Circle parameters
num_layers = 10
height, width = 10, 10
min_curve, max_curve = 15, 50
noise = False
event_size_min, event_size_max = 4, 12 #I.E. The number of true particle tracks
# Please try both cuts!
#max_angle=(4/6)*np.pi
max_angle=(6/6)*np.pi
feature_scale = np.array([10,10])

# %%
# Some dumb circle calculations
def y1(x, r, a, sign):
    return sign*np.sqrt(r**2 - a**2) + np.sqrt(r**2 - (x-a)**2)
def y2(x, r, a, sign):
    return sign*np.sqrt(r**2 - a**2) - np.sqrt(r**2 - (x-a)**2)

# Generate random circle / helix parameters
def rand_pars(event_size_min, event_size_max, max_curve, min_curve):
    event_size = int(np.floor(np.random.random(1)*(event_size_max - event_size_min) + event_size_min))
    radii = np.random.random(event_size)*(max_curve - min_curve) + min_curve
    dirs = np.random.random(event_size)*(radii)*2 -radii
    sign_options = np.array([-1,1])
    signs = sign_options[np.rint(np.random.random(event_size)).astype(int)]
    return radii, dirs, signs, event_size

def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=value, max=max))

# Generate event data from random parameters
def gen_edge_class(event_size_min, event_size_max, curve_min, curve_max, height, num_layers, max_angle, feature_scale, iter, num_samples):
    
    """ Feed params into randomiser """
    while True:
        radii, dirs, signs, event_size = rand_pars(event_size_min, event_size_max, curve_max, curve_min)
        xys = []
        X = np.empty([3,1])
        x = np.arange(0 + height/num_layers,height + height/num_layers, height/num_layers)
        i = 0
        for r, d, s in zip(radii, dirs, signs):
            y1test = y1(x, r, d, s)
        #     print(y1test, x)
            y2test = y2(x, r, d, s)
            if -2.5 < y1test[0] < 2.5 and not any(np.isnan(y1test)):
                X = np.append(X, np.vstack((y1test, np.array([i]*len(y1test)), x )), axis=1)
                i += 1
            if -2.5 < y2test[0] < 2.5 and not any(np.isnan(y2test)):
                X = np.append(X, np.vstack((y2test, np.array([i]*len(y2test)), x )), axis=1)
                i += 1
        X = X[:,1:].T
        np.random.shuffle(X)

        e = np.array([[i,j] for layer in np.arange(num_layers-1) for i in np.argwhere(X[:,2] == layer+1) for j in np.argwhere(X[:,2] == (layer+2)) if (X[i, 0] - np.tan(max_angle/2) < X[j, 0] < X[i, 0] + np.tan(max_angle/2))]).T.squeeze()
        
        # This handles when no edges were constructed. In that case, the randomisation is a do-over
        try:
            y = np.array([int(i[1] == j[1]) for i,j in zip(X[e[0]], X[e[1]])])    
            break
        except:
            pass
    if iter is not None and num_samples is not None:
        out.update(progress(iter, num_samples))    
    
    X = np.array([X[:,2], X[:,0]]).T / feature_scale

    data = Data(x = torch.from_numpy(X).float(), edge_index = torch.from_numpy(e), y = torch.from_numpy(y), pid = torch.from_numpy(X[:,1]))
    return data

# %%
train_size, test_size = 1000, 1000
out = display(progress(0, train_size), display_id=True)
train_dataset = [gen_edge_class(event_size_min, event_size_max, max_curve, min_curve, height, num_layers, max_angle, feature_scale, i, train_size) for i in range(train_size)]
out = display(progress(0, test_size), display_id=True)
test_dataset = [gen_edge_class(event_size_min, event_size_max, max_curve, min_curve, height, num_layers, max_angle, feature_scale, i, test_size) for i in range(test_size)]
train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=True)
# Out:
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
def plot_toy_graph(event):
    plt.figure(figsize=(10,5))
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    e = event.edge_index.numpy()
#     for i, j in zip(X[e[0]], X[e[1]]):
#         plt.plot([i[0], j[0]], [i[1], j[1]], c='b')
    #     print(i[0], i[2], j[0], j[2])
    plt.plot([x[e[0,:]], x[e[1,:]]], [y[e[0,:]], y[e[1,:]]], c='b')
    plt.scatter(x, y, c='k')
    #plt.ylim(-1,1)

# %%
for i in range(5):
    plot_toy_graph(test_dataset[i])

# %% [markdown]
# The complexity of the graph depends on the angle cut we put on it. Try increasing max_angle to, say, `(5/6)*np.pi` and the graph should be more busy. The limit is of course `(6/6)*np.pi = pi` where each node will look at the full angle of available possible nodes to form an edge with. While playing with this number, run the next cell to see the proportion of fake edges to true edges (fake/true) on the above graph. This value will be extremely useful later.

# %%
print("Fake / True = ", (len(train_dataset[0].y) - train_dataset[0].y.sum().item()) / train_dataset[0].y.sum().item())
# Out:
# Fake / True =  5.0

# %% [markdown]
# ## A Simple GNN

# %% [markdown]
# ### Message Passing GNN

# %% [markdown]
# We can write out the full GNN as a class `MPNN_Network`. One can see its behaviour as:
# 1. Encode (x,y) features as hidden features with an N-layer MLP called `node_encoder`
# 2. Concatenate these along each edge, and feed the concatenated features into another MLP called `edge_network`
# 3. Sum the output of `edge_classifier` at each node (that is, each node receives the sum of the "messages" of all connecting edges). This sum is fed into `node_network`
# 4. Add the hidden features to the previous iteration (this helps to preserve information between messages)
# 5. Repeat (2) --> (4) n_graph_iters times
# 6. After the message passing loop, pass the features of each edge through an output classifier network called `edge_classifier`

# %%
def make_mlp(input_size, sizes,
             hidden_activation='ReLU',
             output_activation='ReLU',
             layer_norm=False):
    """Construct an MLP with specified fully-connected layers."""
    hidden_activation = getattr(nn, hidden_activation)
    if output_activation is not None:
        output_activation = getattr(nn, output_activation)
    layers = []
    n_layers = len(sizes)
    sizes = [input_size] + sizes
    # Hidden layers
    for i in range(n_layers-1):
        layers.append(nn.Linear(sizes[i], sizes[i+1]))
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[i+1]))
        layers.append(hidden_activation())
    # Final layer
    layers.append(nn.Linear(sizes[-2], sizes[-1]))
    if output_activation is not None:
        if layer_norm:
            layers.append(nn.LayerNorm(sizes[-1]))
        layers.append(output_activation())
    return nn.Sequential(*layers)

class MPNN_Network(nn.Module):
    """
    A message-passing graph network which takes a graph with:
    - bi-directional edges
    - node features, no edge features

    and applies the following modules:
    - a graph encoder (no message passing)
    - recurrent edge and node networks
    - an edge classifier
    """

    def __init__(self, input_dim, hidden_node_dim, hidden_edge_dim, in_layers, node_layers, edge_layers,
                 n_graph_iters=1, layer_norm=True):
        super(MPNN_Network, self).__init__()
        self.n_graph_iters = n_graph_iters

        # The node encoder transforms input node features to the hidden space
        self.node_encoder = make_mlp(input_dim, [hidden_node_dim]*in_layers)

        # The edge network computes new edge features from connected nodes
        self.edge_network = make_mlp(2*hidden_node_dim,
                                     [hidden_edge_dim]*edge_layers,
                                     layer_norm=layer_norm)

        # The node network computes new node features
        self.node_network = make_mlp(hidden_node_dim + hidden_edge_dim,
                                     [hidden_node_dim]*node_layers,
                                     layer_norm=layer_norm)

        # The edge classifier computes final edge scores
        self.edge_classifier = make_mlp(2*hidden_node_dim,
                                        [hidden_edge_dim, 1],
                                        output_activation=None)

    def forward(self, data):
        # Make every edge bi-directional
        send_idx = torch.cat([data.edge_index[0], data.edge_index[1]], dim=0)
        recv_idx = torch.cat([data.edge_index[1], data.edge_index[0]], dim=0)

        # Encode the graph features into the hidden space
        x = self.node_encoder(data.x)

        # Loop over graph iterations
        for i in range(self.n_graph_iters):

            # Previous hidden state
            x0 = x

            # Compute new edge features
            edge_inputs = torch.cat([x[send_idx], x[recv_idx]], dim=1)
            e = self.edge_network(edge_inputs)

            # Sum edge features coming into each node
            aggr_messages = scatter_add(e, recv_idx, dim=0, dim_size=x.shape[0])

            # Compute new node features
            node_inputs = torch.cat([x, aggr_messages], dim=1)
            x = self.node_network(node_inputs)

            # Residual connection
            x = x + x0

        # Compute final edge scores; use original edge directions only
        start_idx, end_idx = data.edge_index
        clf_inputs = torch.cat([x[start_idx], x[end_idx]], dim=1)
        return self.edge_classifier(clf_inputs).squeeze(-1)

# %% [markdown]
# Build a version of the model and print it out.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
m_configs = {"input_dim": 2, "hidden_node_dim": 64, "hidden_edge_dim": 64, "in_layers": 2, "node_layers": 4, "edge_layers": 4, "n_graph_iters": 1, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)
model
# Out:
# MPNN_Network(
#   (node_encoder): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#   )
#   (edge_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (node_network): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#     (9): Linear(in_features=64, out_features=64, bias=True)
#     (10): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (11): ReLU()
#   )
#   (edge_classifier): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### Training on Toy Data

# %%
def train(model, train_loader, optimizer, weight):
    correct = 0
    total = 0
    total_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        data = batch.to(device)
        pred = model(data)
        loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

def evaluate(model, test_loader, weight):
    correct = 0
    total = 0
    total_loss = 0
    for batch in test_loader:
        data = batch.to(device)
        pred = model(data)
        loss = F.binary_cross_entropy_with_logits(pred.float(), data.y.float(), pos_weight=torch.tensor(weight))
        total_loss += loss.item()
        correct += ((pred > 0.5) == (data.y > 0.5)).sum().item()
        total += len(pred)
    acc = correct/total
    return acc, total_loss

# %%
t_loss_v = []
t_acc_v = []
v_loss_v = []
v_acc_v = []
ep = 0

# %% [markdown]
# We set a weight value that is more or less the (fake / true) ratio found above. This forces the loss function to punish incorrectly classified true edges more severely. It rebalances the distribution as if there was a 1:1 true:fake ratio.

# %% [markdown]
# ### Important:
#
# try various numbers of epochs, to save time train with fewer epochs (let say 200)

# %% [markdown]
# ### Exercise
#
# You can use a static number of epochs, but to save time, you can also add a stop condition for the learning process.
#
# Try to implement stopping after 10 epochs without improvement in the accuracy.
#
# It is also a good practice to store the model, that returned the best values - usually it won't be the last one in the process of training.

# %%
# %%time

epochs = 1000
weight = 2

m_configs = {"input_dim": 2, "hidden_node_dim": 16, "hidden_edge_dim": 16, "in_layers": 1, "node_layers": 2, "edge_layers": 2, "n_graph_iters": 6, "layer_norm": True}
model = MPNN_Network(**m_configs).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-3, amsgrad=True)

for epoch in range(epochs):
    ep += 1  
    model.train()
    acc, total_loss = train(model, train_loader, optimizer, weight)
    t_loss_v.append(total_loss)
    t_acc_v.append(acc)

    model.eval()
    v_acc, v_total_loss = evaluate(model, test_loader, weight)
    v_loss_v.append(v_total_loss)
    v_acc_v.append(v_acc)

    print('Epoch: {}, Train accuracy: {:.4f}, val accuracy: {:.4f}'.format(ep, acc, v_acc))
# Out:
# Epoch: 1, Train accuracy: 0.8478, val accuracy: 0.8500
# Epoch: 2, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 3, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 4, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 5, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 6, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 7, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 8, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 9, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 10, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 11, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 12, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 13, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 14, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 15, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 16, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 17, Train accuracy: 0.8513, val accuracy: 0.8500
# Epoch: 18, Train accuracy: 0.8513, val accuracy: 0.8501
# Epoch: 19, Train accuracy: 0.8514, val accuracy: 0.8502
# Epoch: 20, Train accuracy: 0.8516, val accuracy: 0.8505
# Epoch: 21, Train accuracy: 0.8516, val accuracy: 0.8503
# Epoch: 22, Train accuracy: 0.8514, val accuracy: 0.8500
# Epoch: 23, Train accuracy: 0.8513, val accuracy: 0.8501
# Epoch: 24, Train accuracy: 0.8514, val accuracy: 0.8500
# Epoch: 25, Train accuracy: 0.8515, val accuracy: 0.8507
# Epoch: 26, Train accuracy: 0.8536, val accuracy: 0.8544
# Epoch: 27, Train accuracy: 0.8564, val accuracy: 0.8566
# Epoch: 28, Train accuracy: 0.8582, val accuracy: 0.8569
# Epoch: 29, Train accuracy: 0.8574, val accuracy: 0.8583
# Epoch: 30, Train accuracy: 0.8588, val accuracy: 0.8578
# Epoch: 31, Train accuracy: 0.8621, val accuracy: 0.8633
# Epoch: 32, Train accuracy: 0.8658, val accuracy: 0.8663
# Epoch: 33, Train accuracy: 0.8705, val accuracy: 0.8749
# Epoch: 34, Train accuracy: 0.8764, val accuracy: 0.8779
# Epoch: 35, Train accuracy: 0.8819, val accuracy: 0.8811
# Epoch: 36, Train accuracy: 0.8879, val accuracy: 0.8950
# Epoch: 37, Train accuracy: 0.8956, val accuracy: 0.9046
# Epoch: 38, Train accuracy: 0.9037, val accuracy: 0.9092
# Epoch: 39, Train accuracy: 0.9114, val accuracy: 0.9184
# Epoch: 40, Train accuracy: 0.9206, val accuracy: 0.9295
# Epoch: 41, Train accuracy: 0.9283, val accuracy: 0.9321
# Epoch: 42, Train accuracy: 0.9353, val accuracy: 0.9405
# Epoch: 43, Train accuracy: 0.9399, val accuracy: 0.9409
# Epoch: 44, Train accuracy: 0.9467, val accuracy: 0.9535
# Epoch: 45, Train accuracy: 0.9517, val accuracy: 0.9534
# Epoch: 46, Train accuracy: 0.9545, val accuracy: 0.9565
# Epoch: 47, Train accuracy: 0.9566, val accuracy: 0.9615
# Epoch: 48, Train accuracy: 0.9591, val accuracy: 0.9624
# Epoch: 49, Train accuracy: 0.9619, val accuracy: 0.9660
# Epoch: 50, Train accuracy: 0.9641, val accuracy: 0.9655
# Epoch: 51, Train accuracy: 0.9655, val accuracy: 0.9653
# Epoch: 52, Train accuracy: 0.9664, val accuracy: 0.9686
# Epoch: 53, Train accuracy: 0.9674, val accuracy: 0.9681
# Epoch: 54, Train accuracy: 0.9677, val accuracy: 0.9685
# Epoch: 55, Train accuracy: 0.9692, val accuracy: 0.9697
# Epoch: 56, Train accuracy: 0.9694, val accuracy: 0.9695
# Epoch: 57, Train accuracy: 0.9685, val accuracy: 0.9658
# Epoch: 58, Train accuracy: 0.9692, val accuracy: 0.9706
# Epoch: 59, Train accuracy: 0.9704, val accuracy: 0.9659
# Epoch: 60, Train accuracy: 0.9700, val accuracy: 0.9720
# Epoch: 61, Train accuracy: 0.9711, val accuracy: 0.9723
# Epoch: 62, Train accuracy: 0.9711, val accuracy: 0.9731
# Epoch: 63, Train accuracy: 0.9719, val accuracy: 0.9717
# Epoch: 64, Train accuracy: 0.9717, val accuracy: 0.9722
# Epoch: 65, Train accuracy: 0.9720, val accuracy: 0.9730
# Epoch: 66, Train accuracy: 0.9728, val accuracy: 0.9731
# Epoch: 67, Train accuracy: 0.9726, val accuracy: 0.9733
# Epoch: 68, Train accuracy: 0.9729, val accuracy: 0.9737
# Epoch: 69, Train accuracy: 0.9734, val accuracy: 0.9737
# Epoch: 70, Train accuracy: 0.9732, val accuracy: 0.9737
# Epoch: 71, Train accuracy: 0.9736, val accuracy: 0.9739
# Epoch: 72, Train accuracy: 0.9736, val accuracy: 0.9740
# Epoch: 73, Train accuracy: 0.9739, val accuracy: 0.9748
# Epoch: 74, Train accuracy: 0.9744, val accuracy: 0.9750
# Epoch: 75, Train accuracy: 0.9744, val accuracy: 0.9746
# Epoch: 76, Train accuracy: 0.9742, val accuracy: 0.9746
# Epoch: 77, Train accuracy: 0.9740, val accuracy: 0.9753
# Epoch: 78, Train accuracy: 0.9744, val accuracy: 0.9753
# Epoch: 79, Train accuracy: 0.9747, val accuracy: 0.9754
# Epoch: 80, Train accuracy: 0.9752, val accuracy: 0.9756
# Epoch: 81, Train accuracy: 0.9753, val accuracy: 0.9749
# Epoch: 82, Train accuracy: 0.9746, val accuracy: 0.9748
# Epoch: 83, Train accuracy: 0.9746, val accuracy: 0.9747
# Epoch: 84, Train accuracy: 0.9746, val accuracy: 0.9756
# Epoch: 85, Train accuracy: 0.9752, val accuracy: 0.9757
# Epoch: 86, Train accuracy: 0.9754, val accuracy: 0.9760
# Epoch: 87, Train accuracy: 0.9756, val accuracy: 0.9759
# Epoch: 88, Train accuracy: 0.9755, val accuracy: 0.9764
# Epoch: 89, Train accuracy: 0.9755, val accuracy: 0.9757
# Epoch: 90, Train accuracy: 0.9756, val accuracy: 0.9767
# Epoch: 91, Train accuracy: 0.9762, val accuracy: 0.9757
# Epoch: 92, Train accuracy: 0.9761, val accuracy: 0.9765
# Epoch: 93, Train accuracy: 0.9765, val accuracy: 0.9764
# Epoch: 94, Train accuracy: 0.9762, val accuracy: 0.9762
# Epoch: 95, Train accuracy: 0.9763, val accuracy: 0.9762
# Epoch: 96, Train accuracy: 0.9760, val accuracy: 0.9761
# Epoch: 97, Train accuracy: 0.9762, val accuracy: 0.9762
# Epoch: 98, Train accuracy: 0.9762, val accuracy: 0.9760
# Epoch: 99, Train accuracy: 0.9761, val accuracy: 0.9768
# Epoch: 100, Train accuracy: 0.9765, val accuracy: 0.9769
# Epoch: 101, Train accuracy: 0.9765, val accuracy: 0.9769
# Epoch: 102, Train accuracy: 0.9768, val accuracy: 0.9769
# Epoch: 103, Train accuracy: 0.9768, val accuracy: 0.9769
# Epoch: 104, Train accuracy: 0.9764, val accuracy: 0.9776
# Epoch: 105, Train accuracy: 0.9766, val accuracy: 0.9772
# Epoch: 106, Train accuracy: 0.9766, val accuracy: 0.9769
# Epoch: 107, Train accuracy: 0.9767, val accuracy: 0.9773
# Epoch: 108, Train accuracy: 0.9767, val accuracy: 0.9773
# Epoch: 109, Train accuracy: 0.9770, val accuracy: 0.9777
# Epoch: 110, Train accuracy: 0.9772, val accuracy: 0.9774
# Epoch: 111, Train accuracy: 0.9772, val accuracy: 0.9772
# Epoch: 112, Train accuracy: 0.9766, val accuracy: 0.9773
# Epoch: 113, Train accuracy: 0.9772, val accuracy: 0.9769
# Epoch: 114, Train accuracy: 0.9768, val accuracy: 0.9776
# Epoch: 115, Train accuracy: 0.9772, val accuracy: 0.9776
# Epoch: 116, Train accuracy: 0.9770, val accuracy: 0.9775
# Epoch: 117, Train accuracy: 0.9771, val accuracy: 0.9770
# Epoch: 118, Train accuracy: 0.9773, val accuracy: 0.9778
# Epoch: 119, Train accuracy: 0.9774, val accuracy: 0.9774
# Epoch: 120, Train accuracy: 0.9772, val accuracy: 0.9773
# Epoch: 121, Train accuracy: 0.9773, val accuracy: 0.9775
# Epoch: 122, Train accuracy: 0.9775, val accuracy: 0.9778
# Epoch: 123, Train accuracy: 0.9778, val accuracy: 0.9780
# Epoch: 124, Train accuracy: 0.9779, val accuracy: 0.9780
# Epoch: 125, Train accuracy: 0.9776, val accuracy: 0.9776
# Epoch: 126, Train accuracy: 0.9777, val accuracy: 0.9779
# Epoch: 127, Train accuracy: 0.9778, val accuracy: 0.9780
# Epoch: 128, Train accuracy: 0.9776, val accuracy: 0.9780
# Epoch: 129, Train accuracy: 0.9775, val accuracy: 0.9776
# Epoch: 130, Train accuracy: 0.9775, val accuracy: 0.9781
# Epoch: 131, Train accuracy: 0.9775, val accuracy: 0.9777
# Epoch: 132, Train accuracy: 0.9773, val accuracy: 0.9780
# Epoch: 133, Train accuracy: 0.9774, val accuracy: 0.9779
# Epoch: 134, Train accuracy: 0.9773, val accuracy: 0.9777
# Epoch: 135, Train accuracy: 0.9778, val accuracy: 0.9781
# Epoch: 136, Train accuracy: 0.9780, val accuracy: 0.9780
# Epoch: 137, Train accuracy: 0.9780, val accuracy: 0.9780
# Epoch: 138, Train accuracy: 0.9780, val accuracy: 0.9776
# Epoch: 139, Train accuracy: 0.9778, val accuracy: 0.9781
# Epoch: 140, Train accuracy: 0.9778, val accuracy: 0.9780
# Epoch: 141, Train accuracy: 0.9780, val accuracy: 0.9780
# Epoch: 142, Train accuracy: 0.9779, val accuracy: 0.9779
# Epoch: 143, Train accuracy: 0.9780, val accuracy: 0.9784
# Epoch: 144, Train accuracy: 0.9775, val accuracy: 0.9772
# Epoch: 145, Train accuracy: 0.9778, val accuracy: 0.9787
# Epoch: 146, Train accuracy: 0.9784, val accuracy: 0.9784
# Epoch: 147, Train accuracy: 0.9779, val accuracy: 0.9785
# Epoch: 148, Train accuracy: 0.9781, val accuracy: 0.9785
# Epoch: 149, Train accuracy: 0.9781, val accuracy: 0.9786
# Epoch: 150, Train accuracy: 0.9783, val accuracy: 0.9785
# Epoch: 151, Train accuracy: 0.9785, val accuracy: 0.9785
# Epoch: 152, Train accuracy: 0.9783, val accuracy: 0.9789
# Epoch: 153, Train accuracy: 0.9784, val accuracy: 0.9778
# Epoch: 154, Train accuracy: 0.9780, val accuracy: 0.9785
# Epoch: 155, Train accuracy: 0.9784, val accuracy: 0.9787
# Epoch: 156, Train accuracy: 0.9783, val accuracy: 0.9790
# Epoch: 157, Train accuracy: 0.9784, val accuracy: 0.9788
# Epoch: 158, Train accuracy: 0.9784, val accuracy: 0.9787
# Epoch: 159, Train accuracy: 0.9783, val accuracy: 0.9792
# Epoch: 160, Train accuracy: 0.9784, val accuracy: 0.9786
# Epoch: 161, Train accuracy: 0.9781, val accuracy: 0.9785
# Epoch: 162, Train accuracy: 0.9785, val accuracy: 0.9787
# Epoch: 163, Train accuracy: 0.9784, val accuracy: 0.9787
# Epoch: 164, Train accuracy: 0.9785, val accuracy: 0.9786
# Epoch: 165, Train accuracy: 0.9784, val accuracy: 0.9790
# Epoch: 166, Train accuracy: 0.9787, val accuracy: 0.9791
# Epoch: 167, Train accuracy: 0.9783, val accuracy: 0.9789
# Epoch: 168, Train accuracy: 0.9785, val accuracy: 0.9789
# Epoch: 169, Train accuracy: 0.9783, val accuracy: 0.9787
# Epoch: 170, Train accuracy: 0.9787, val accuracy: 0.9786
# Epoch: 171, Train accuracy: 0.9784, val accuracy: 0.9785
# Epoch: 172, Train accuracy: 0.9788, val accuracy: 0.9789
# Epoch: 173, Train accuracy: 0.9788, val accuracy: 0.9793
# Epoch: 174, Train accuracy: 0.9789, val accuracy: 0.9791
# Epoch: 175, Train accuracy: 0.9786, val accuracy: 0.9786
# Epoch: 176, Train accuracy: 0.9788, val accuracy: 0.9793
# Epoch: 177, Train accuracy: 0.9787, val accuracy: 0.9789
# Epoch: 178, Train accuracy: 0.9787, val accuracy: 0.9787
# Epoch: 179, Train accuracy: 0.9785, val accuracy: 0.9789
# Epoch: 180, Train accuracy: 0.9785, val accuracy: 0.9790
# Epoch: 181, Train accuracy: 0.9784, val accuracy: 0.9792
# Epoch: 182, Train accuracy: 0.9788, val accuracy: 0.9790
# Epoch: 183, Train accuracy: 0.9788, val accuracy: 0.9792
# Epoch: 184, Train accuracy: 0.9788, val accuracy: 0.9788
# Epoch: 185, Train accuracy: 0.9787, val accuracy: 0.9793
# Epoch: 186, Train accuracy: 0.9784, val accuracy: 0.9781
# Epoch: 187, Train accuracy: 0.9781, val accuracy: 0.9788
# Epoch: 188, Train accuracy: 0.9781, val accuracy: 0.9788
# Epoch: 189, Train accuracy: 0.9783, val accuracy: 0.9789
# Epoch: 190, Train accuracy: 0.9786, val accuracy: 0.9794
# Epoch: 191, Train accuracy: 0.9787, val accuracy: 0.9794
# Epoch: 192, Train accuracy: 0.9788, val accuracy: 0.9796
# Epoch: 193, Train accuracy: 0.9789, val accuracy: 0.9795
# Epoch: 194, Train accuracy: 0.9790, val accuracy: 0.9792
# Epoch: 195, Train accuracy: 0.9790, val accuracy: 0.9794
# Epoch: 196, Train accuracy: 0.9787, val accuracy: 0.9792
# Epoch: 197, Train accuracy: 0.9786, val accuracy: 0.9782
# Epoch: 198, Train accuracy: 0.9787, val accuracy: 0.9788
# Epoch: 199, Train accuracy: 0.9787, val accuracy: 0.9792
# Epoch: 200, Train accuracy: 0.9791, val accuracy: 0.9789
# Epoch: 201, Train accuracy: 0.9791, val accuracy: 0.9793
# Epoch: 202, Train accuracy: 0.9790, val accuracy: 0.9792
# Epoch: 203, Train accuracy: 0.9789, val accuracy: 0.9794
# Epoch: 204, Train accuracy: 0.9788, val accuracy: 0.9794
# Epoch: 205, Train accuracy: 0.9791, val accuracy: 0.9792
# Epoch: 206, Train accuracy: 0.9791, val accuracy: 0.9792
# Epoch: 207, Train accuracy: 0.9792, val accuracy: 0.9789
# Epoch: 208, Train accuracy: 0.9791, val accuracy: 0.9792
# Epoch: 209, Train accuracy: 0.9789, val accuracy: 0.9793
# Epoch: 210, Train accuracy: 0.9790, val accuracy: 0.9794
# Epoch: 211, Train accuracy: 0.9787, val accuracy: 0.9780
# Epoch: 212, Train accuracy: 0.9785, val accuracy: 0.9788
# Epoch: 213, Train accuracy: 0.9789, val accuracy: 0.9791
# Epoch: 214, Train accuracy: 0.9790, val accuracy: 0.9791
# Epoch: 215, Train accuracy: 0.9789, val accuracy: 0.9785
# Epoch: 216, Train accuracy: 0.9783, val accuracy: 0.9792
# Epoch: 217, Train accuracy: 0.9786, val accuracy: 0.9790
# Epoch: 218, Train accuracy: 0.9784, val accuracy: 0.9780
# Epoch: 219, Train accuracy: 0.9783, val accuracy: 0.9789
# Epoch: 220, Train accuracy: 0.9790, val accuracy: 0.9793
# Epoch: 221, Train accuracy: 0.9791, val accuracy: 0.9793
# Epoch: 222, Train accuracy: 0.9790, val accuracy: 0.9795
# Epoch: 223, Train accuracy: 0.9789, val accuracy: 0.9790
# Epoch: 224, Train accuracy: 0.9788, val accuracy: 0.9781
# Epoch: 225, Train accuracy: 0.9784, val accuracy: 0.9792
# Epoch: 226, Train accuracy: 0.9790, val accuracy: 0.9793
# Epoch: 227, Train accuracy: 0.9791, val accuracy: 0.9794
# Epoch: 228, Train accuracy: 0.9790, val accuracy: 0.9791
# Epoch: 229, Train accuracy: 0.9793, val accuracy: 0.9787
# Epoch: 230, Train accuracy: 0.9790, val accuracy: 0.9791
# Epoch: 231, Train accuracy: 0.9793, val accuracy: 0.9796
# Epoch: 232, Train accuracy: 0.9788, val accuracy: 0.9793
# Epoch: 233, Train accuracy: 0.9794, val accuracy: 0.9795
# Epoch: 234, Train accuracy: 0.9795, val accuracy: 0.9793
# Epoch: 235, Train accuracy: 0.9790, val accuracy: 0.9797
# Epoch: 236, Train accuracy: 0.9790, val accuracy: 0.9795
# Epoch: 237, Train accuracy: 0.9786, val accuracy: 0.9792
# Epoch: 238, Train accuracy: 0.9786, val accuracy: 0.9793
# Epoch: 239, Train accuracy: 0.9790, val accuracy: 0.9789
# Epoch: 240, Train accuracy: 0.9789, val accuracy: 0.9791
# Epoch: 241, Train accuracy: 0.9790, val accuracy: 0.9799
# Epoch: 242, Train accuracy: 0.9792, val accuracy: 0.9797
# Epoch: 243, Train accuracy: 0.9792, val accuracy: 0.9797
# Epoch: 244, Train accuracy: 0.9792, val accuracy: 0.9794
# Epoch: 245, Train accuracy: 0.9793, val accuracy: 0.9794
# Epoch: 246, Train accuracy: 0.9792, val accuracy: 0.9799
# Epoch: 247, Train accuracy: 0.9794, val accuracy: 0.9798
# Epoch: 248, Train accuracy: 0.9795, val accuracy: 0.9796
# Epoch: 249, Train accuracy: 0.9792, val accuracy: 0.9797
# Epoch: 250, Train accuracy: 0.9787, val accuracy: 0.9787
# Epoch: 251, Train accuracy: 0.9788, val accuracy: 0.9796
# Epoch: 252, Train accuracy: 0.9793, val accuracy: 0.9801
# Epoch: 253, Train accuracy: 0.9794, val accuracy: 0.9794
# Epoch: 254, Train accuracy: 0.9791, val accuracy: 0.9795
# Epoch: 255, Train accuracy: 0.9796, val accuracy: 0.9800
# Epoch: 256, Train accuracy: 0.9794, val accuracy: 0.9798
# Epoch: 257, Train accuracy: 0.9794, val accuracy: 0.9800
# Epoch: 258, Train accuracy: 0.9795, val accuracy: 0.9795
# Epoch: 259, Train accuracy: 0.9788, val accuracy: 0.9797
# Epoch: 260, Train accuracy: 0.9792, val accuracy: 0.9798
# Epoch: 261, Train accuracy: 0.9795, val accuracy: 0.9797
# Epoch: 262, Train accuracy: 0.9794, val accuracy: 0.9797
# Epoch: 263, Train accuracy: 0.9793, val accuracy: 0.9796
# Epoch: 264, Train accuracy: 0.9792, val accuracy: 0.9794
# Epoch: 265, Train accuracy: 0.9794, val accuracy: 0.9796
# Epoch: 266, Train accuracy: 0.9796, val accuracy: 0.9792
# Epoch: 267, Train accuracy: 0.9796, val accuracy: 0.9796
# Epoch: 268, Train accuracy: 0.9796, val accuracy: 0.9798
# Epoch: 269, Train accuracy: 0.9797, val accuracy: 0.9798
# Epoch: 270, Train accuracy: 0.9795, val accuracy: 0.9798
# Epoch: 271, Train accuracy: 0.9797, val accuracy: 0.9796
# Epoch: 272, Train accuracy: 0.9795, val accuracy: 0.9796
# Epoch: 273, Train accuracy: 0.9796, val accuracy: 0.9797
# Epoch: 274, Train accuracy: 0.9795, val accuracy: 0.9795
# Epoch: 275, Train accuracy: 0.9791, val accuracy: 0.9796
# Epoch: 276, Train accuracy: 0.9793, val accuracy: 0.9800
# Epoch: 277, Train accuracy: 0.9798, val accuracy: 0.9800
# Epoch: 278, Train accuracy: 0.9796, val accuracy: 0.9794
# Epoch: 279, Train accuracy: 0.9794, val accuracy: 0.9794
# Epoch: 280, Train accuracy: 0.9795, val accuracy: 0.9800
# Epoch: 281, Train accuracy: 0.9792, val accuracy: 0.9799
# Epoch: 282, Train accuracy: 0.9795, val accuracy: 0.9803
# Epoch: 283, Train accuracy: 0.9796, val accuracy: 0.9794
# Epoch: 284, Train accuracy: 0.9798, val accuracy: 0.9802
# Epoch: 285, Train accuracy: 0.9798, val accuracy: 0.9802
# Epoch: 286, Train accuracy: 0.9793, val accuracy: 0.9803
# Epoch: 287, Train accuracy: 0.9796, val accuracy: 0.9795
# Epoch: 288, Train accuracy: 0.9799, val accuracy: 0.9801
# Epoch: 289, Train accuracy: 0.9797, val accuracy: 0.9801
# Epoch: 290, Train accuracy: 0.9794, val accuracy: 0.9789
# Epoch: 291, Train accuracy: 0.9795, val accuracy: 0.9797
# Epoch: 292, Train accuracy: 0.9796, val accuracy: 0.9792
# Epoch: 293, Train accuracy: 0.9797, val accuracy: 0.9802
# Epoch: 294, Train accuracy: 0.9796, val accuracy: 0.9793
# Epoch: 295, Train accuracy: 0.9794, val accuracy: 0.9796
# Epoch: 296, Train accuracy: 0.9797, val accuracy: 0.9795
# Epoch: 297, Train accuracy: 0.9799, val accuracy: 0.9799
# Epoch: 298, Train accuracy: 0.9799, val accuracy: 0.9799
# Epoch: 299, Train accuracy: 0.9795, val accuracy: 0.9793
# Epoch: 300, Train accuracy: 0.9789, val accuracy: 0.9795
# Epoch: 301, Train accuracy: 0.9794, val accuracy: 0.9797
# Epoch: 302, Train accuracy: 0.9797, val accuracy: 0.9803
# Epoch: 303, Train accuracy: 0.9801, val accuracy: 0.9802
# Epoch: 304, Train accuracy: 0.9801, val accuracy: 0.9802
# Epoch: 305, Train accuracy: 0.9800, val accuracy: 0.9794
# Epoch: 306, Train accuracy: 0.9795, val accuracy: 0.9795
# Epoch: 307, Train accuracy: 0.9798, val accuracy: 0.9793
# Epoch: 308, Train accuracy: 0.9798, val accuracy: 0.9798
# Epoch: 309, Train accuracy: 0.9796, val accuracy: 0.9797
# Epoch: 310, Train accuracy: 0.9797, val accuracy: 0.9796
# Epoch: 311, Train accuracy: 0.9800, val accuracy: 0.9804
# Epoch: 312, Train accuracy: 0.9798, val accuracy: 0.9798
# Epoch: 313, Train accuracy: 0.9792, val accuracy: 0.9793
# Epoch: 314, Train accuracy: 0.9794, val accuracy: 0.9796
# Epoch: 315, Train accuracy: 0.9797, val accuracy: 0.9793
# Epoch: 316, Train accuracy: 0.9797, val accuracy: 0.9792
# Epoch: 317, Train accuracy: 0.9794, val accuracy: 0.9806
# Epoch: 318, Train accuracy: 0.9800, val accuracy: 0.9802
# Epoch: 319, Train accuracy: 0.9798, val accuracy: 0.9796
# Epoch: 320, Train accuracy: 0.9798, val accuracy: 0.9800
# Epoch: 321, Train accuracy: 0.9799, val accuracy: 0.9795
# Epoch: 322, Train accuracy: 0.9798, val accuracy: 0.9800
# Epoch: 323, Train accuracy: 0.9799, val accuracy: 0.9803
# Epoch: 324, Train accuracy: 0.9796, val accuracy: 0.9802
# Epoch: 325, Train accuracy: 0.9799, val accuracy: 0.9798
# Epoch: 326, Train accuracy: 0.9799, val accuracy: 0.9798
# Epoch: 327, Train accuracy: 0.9797, val accuracy: 0.9801
# Epoch: 328, Train accuracy: 0.9795, val accuracy: 0.9803
# Epoch: 329, Train accuracy: 0.9798, val accuracy: 0.9807
# Epoch: 330, Train accuracy: 0.9801, val accuracy: 0.9804
# Epoch: 331, Train accuracy: 0.9803, val accuracy: 0.9806
# Epoch: 332, Train accuracy: 0.9801, val accuracy: 0.9805
# Epoch: 333, Train accuracy: 0.9801, val accuracy: 0.9803
# Epoch: 334, Train accuracy: 0.9804, val accuracy: 0.9803
# Epoch: 335, Train accuracy: 0.9802, val accuracy: 0.9794
# Epoch: 336, Train accuracy: 0.9800, val accuracy: 0.9796
# Epoch: 337, Train accuracy: 0.9802, val accuracy: 0.9805
# Epoch: 338, Train accuracy: 0.9797, val accuracy: 0.9802
# Epoch: 339, Train accuracy: 0.9799, val accuracy: 0.9804
# Epoch: 340, Train accuracy: 0.9797, val accuracy: 0.9800
# Epoch: 341, Train accuracy: 0.9797, val accuracy: 0.9784
# Epoch: 342, Train accuracy: 0.9791, val accuracy: 0.9770
# Epoch: 343, Train accuracy: 0.9788, val accuracy: 0.9796
# Epoch: 344, Train accuracy: 0.9795, val accuracy: 0.9796
# Epoch: 345, Train accuracy: 0.9800, val accuracy: 0.9799
# Epoch: 346, Train accuracy: 0.9801, val accuracy: 0.9799
# Epoch: 347, Train accuracy: 0.9801, val accuracy: 0.9806
# Epoch: 348, Train accuracy: 0.9803, val accuracy: 0.9801
# Epoch: 349, Train accuracy: 0.9796, val accuracy: 0.9793
# Epoch: 350, Train accuracy: 0.9798, val accuracy: 0.9797
# Epoch: 351, Train accuracy: 0.9801, val accuracy: 0.9806
# Epoch: 352, Train accuracy: 0.9802, val accuracy: 0.9807
# Epoch: 353, Train accuracy: 0.9804, val accuracy: 0.9796
# Epoch: 354, Train accuracy: 0.9798, val accuracy: 0.9796
# Epoch: 355, Train accuracy: 0.9799, val accuracy: 0.9798
# Epoch: 356, Train accuracy: 0.9803, val accuracy: 0.9804
# Epoch: 357, Train accuracy: 0.9804, val accuracy: 0.9793
# Epoch: 358, Train accuracy: 0.9801, val accuracy: 0.9800
# Epoch: 359, Train accuracy: 0.9803, val accuracy: 0.9796
# Epoch: 360, Train accuracy: 0.9798, val accuracy: 0.9803
# Epoch: 361, Train accuracy: 0.9802, val accuracy: 0.9803
# Epoch: 362, Train accuracy: 0.9806, val accuracy: 0.9804
# Epoch: 363, Train accuracy: 0.9802, val accuracy: 0.9800
# Epoch: 364, Train accuracy: 0.9802, val accuracy: 0.9802
# Epoch: 365, Train accuracy: 0.9804, val accuracy: 0.9805
# Epoch: 366, Train accuracy: 0.9804, val accuracy: 0.9804
# Epoch: 367, Train accuracy: 0.9804, val accuracy: 0.9806
# Epoch: 368, Train accuracy: 0.9804, val accuracy: 0.9807
# Epoch: 369, Train accuracy: 0.9802, val accuracy: 0.9806
# Epoch: 370, Train accuracy: 0.9805, val accuracy: 0.9802
# Epoch: 371, Train accuracy: 0.9805, val accuracy: 0.9807
# Epoch: 372, Train accuracy: 0.9804, val accuracy: 0.9805
# Epoch: 373, Train accuracy: 0.9802, val accuracy: 0.9805
# Epoch: 374, Train accuracy: 0.9804, val accuracy: 0.9806
# Epoch: 375, Train accuracy: 0.9805, val accuracy: 0.9805
# Epoch: 376, Train accuracy: 0.9804, val accuracy: 0.9798
# Epoch: 377, Train accuracy: 0.9802, val accuracy: 0.9799
# Epoch: 378, Train accuracy: 0.9801, val accuracy: 0.9805
# Epoch: 379, Train accuracy: 0.9801, val accuracy: 0.9803
# Epoch: 380, Train accuracy: 0.9804, val accuracy: 0.9805
# Epoch: 381, Train accuracy: 0.9804, val accuracy: 0.9806
# Epoch: 382, Train accuracy: 0.9802, val accuracy: 0.9805
# Epoch: 383, Train accuracy: 0.9803, val accuracy: 0.9805
# Epoch: 384, Train accuracy: 0.9805, val accuracy: 0.9803
# Epoch: 385, Train accuracy: 0.9798, val accuracy: 0.9800
# Epoch: 386, Train accuracy: 0.9798, val accuracy: 0.9805
# Epoch: 387, Train accuracy: 0.9797, val accuracy: 0.9798
# Epoch: 388, Train accuracy: 0.9799, val accuracy: 0.9806
# Epoch: 389, Train accuracy: 0.9803, val accuracy: 0.9803
# Epoch: 390, Train accuracy: 0.9805, val accuracy: 0.9798
# Epoch: 391, Train accuracy: 0.9802, val accuracy: 0.9801
# Epoch: 392, Train accuracy: 0.9797, val accuracy: 0.9804
# Epoch: 393, Train accuracy: 0.9800, val accuracy: 0.9793
# Epoch: 394, Train accuracy: 0.9794, val accuracy: 0.9799
# Epoch: 395, Train accuracy: 0.9799, val accuracy: 0.9809
# Epoch: 396, Train accuracy: 0.9802, val accuracy: 0.9804
# Epoch: 397, Train accuracy: 0.9804, val accuracy: 0.9799
# Epoch: 398, Train accuracy: 0.9804, val accuracy: 0.9799
# Epoch: 399, Train accuracy: 0.9806, val accuracy: 0.9804
# Epoch: 400, Train accuracy: 0.9803, val accuracy: 0.9804
# Epoch: 401, Train accuracy: 0.9803, val accuracy: 0.9801
# Epoch: 402, Train accuracy: 0.9802, val accuracy: 0.9803
# Epoch: 403, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 404, Train accuracy: 0.9806, val accuracy: 0.9808
# Epoch: 405, Train accuracy: 0.9801, val accuracy: 0.9800
# Epoch: 406, Train accuracy: 0.9802, val accuracy: 0.9799
# Epoch: 407, Train accuracy: 0.9803, val accuracy: 0.9807
# Epoch: 408, Train accuracy: 0.9804, val accuracy: 0.9800
# Epoch: 409, Train accuracy: 0.9799, val accuracy: 0.9804
# Epoch: 410, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 411, Train accuracy: 0.9803, val accuracy: 0.9808
# Epoch: 412, Train accuracy: 0.9807, val accuracy: 0.9809
# Epoch: 413, Train accuracy: 0.9802, val accuracy: 0.9805
# Epoch: 414, Train accuracy: 0.9806, val accuracy: 0.9810
# Epoch: 415, Train accuracy: 0.9808, val accuracy: 0.9804
# Epoch: 416, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 417, Train accuracy: 0.9798, val accuracy: 0.9790
# Epoch: 418, Train accuracy: 0.9801, val accuracy: 0.9809
# Epoch: 419, Train accuracy: 0.9805, val accuracy: 0.9807
# Epoch: 420, Train accuracy: 0.9805, val accuracy: 0.9801
# Epoch: 421, Train accuracy: 0.9803, val accuracy: 0.9805
# Epoch: 422, Train accuracy: 0.9804, val accuracy: 0.9803
# Epoch: 423, Train accuracy: 0.9803, val accuracy: 0.9803
# Epoch: 424, Train accuracy: 0.9807, val accuracy: 0.9806
# Epoch: 425, Train accuracy: 0.9799, val accuracy: 0.9799
# Epoch: 426, Train accuracy: 0.9797, val accuracy: 0.9805
# Epoch: 427, Train accuracy: 0.9803, val accuracy: 0.9806
# Epoch: 428, Train accuracy: 0.9803, val accuracy: 0.9806
# Epoch: 429, Train accuracy: 0.9804, val accuracy: 0.9802
# Epoch: 430, Train accuracy: 0.9801, val accuracy: 0.9806
# Epoch: 431, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 432, Train accuracy: 0.9804, val accuracy: 0.9808
# Epoch: 433, Train accuracy: 0.9805, val accuracy: 0.9804
# Epoch: 434, Train accuracy: 0.9806, val accuracy: 0.9804
# Epoch: 435, Train accuracy: 0.9803, val accuracy: 0.9804
# Epoch: 436, Train accuracy: 0.9804, val accuracy: 0.9801
# Epoch: 437, Train accuracy: 0.9807, val accuracy: 0.9808
# Epoch: 438, Train accuracy: 0.9806, val accuracy: 0.9807
# Epoch: 439, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 440, Train accuracy: 0.9804, val accuracy: 0.9810
# Epoch: 441, Train accuracy: 0.9805, val accuracy: 0.9806
# Epoch: 442, Train accuracy: 0.9801, val accuracy: 0.9800
# Epoch: 443, Train accuracy: 0.9802, val accuracy: 0.9804
# Epoch: 444, Train accuracy: 0.9805, val accuracy: 0.9806
# Epoch: 445, Train accuracy: 0.9803, val accuracy: 0.9801
# Epoch: 446, Train accuracy: 0.9804, val accuracy: 0.9811
# Epoch: 447, Train accuracy: 0.9805, val accuracy: 0.9806
# Epoch: 448, Train accuracy: 0.9805, val accuracy: 0.9806
# Epoch: 449, Train accuracy: 0.9806, val accuracy: 0.9805
# Epoch: 450, Train accuracy: 0.9808, val accuracy: 0.9803
# Epoch: 451, Train accuracy: 0.9809, val accuracy: 0.9805
# Epoch: 452, Train accuracy: 0.9805, val accuracy: 0.9802
# Epoch: 453, Train accuracy: 0.9807, val accuracy: 0.9808
# Epoch: 454, Train accuracy: 0.9807, val accuracy: 0.9798
# Epoch: 455, Train accuracy: 0.9803, val accuracy: 0.9807
# Epoch: 456, Train accuracy: 0.9800, val accuracy: 0.9795
# Epoch: 457, Train accuracy: 0.9804, val accuracy: 0.9803
# Epoch: 458, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 459, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 460, Train accuracy: 0.9808, val accuracy: 0.9807
# Epoch: 461, Train accuracy: 0.9807, val accuracy: 0.9810
# Epoch: 462, Train accuracy: 0.9807, val accuracy: 0.9804
# Epoch: 463, Train accuracy: 0.9805, val accuracy: 0.9809
# Epoch: 464, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 465, Train accuracy: 0.9808, val accuracy: 0.9807
# Epoch: 466, Train accuracy: 0.9808, val accuracy: 0.9805
# Epoch: 467, Train accuracy: 0.9807, val accuracy: 0.9805
# Epoch: 468, Train accuracy: 0.9806, val accuracy: 0.9807
# Epoch: 469, Train accuracy: 0.9808, val accuracy: 0.9805
# Epoch: 470, Train accuracy: 0.9805, val accuracy: 0.9806
# Epoch: 471, Train accuracy: 0.9807, val accuracy: 0.9808
# Epoch: 472, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 473, Train accuracy: 0.9809, val accuracy: 0.9810
# Epoch: 474, Train accuracy: 0.9804, val accuracy: 0.9807
# Epoch: 475, Train accuracy: 0.9808, val accuracy: 0.9803
# Epoch: 476, Train accuracy: 0.9806, val accuracy: 0.9807
# Epoch: 477, Train accuracy: 0.9803, val accuracy: 0.9798
# Epoch: 478, Train accuracy: 0.9797, val accuracy: 0.9800
# Epoch: 479, Train accuracy: 0.9806, val accuracy: 0.9790
# Epoch: 480, Train accuracy: 0.9804, val accuracy: 0.9808
# Epoch: 481, Train accuracy: 0.9807, val accuracy: 0.9807
# Epoch: 482, Train accuracy: 0.9807, val accuracy: 0.9805
# Epoch: 483, Train accuracy: 0.9805, val accuracy: 0.9807
# Epoch: 484, Train accuracy: 0.9807, val accuracy: 0.9808
# Epoch: 485, Train accuracy: 0.9801, val accuracy: 0.9803
# Epoch: 486, Train accuracy: 0.9804, val accuracy: 0.9805
# Epoch: 487, Train accuracy: 0.9808, val accuracy: 0.9806
# Epoch: 488, Train accuracy: 0.9807, val accuracy: 0.9806
# Epoch: 489, Train accuracy: 0.9805, val accuracy: 0.9809
# Epoch: 490, Train accuracy: 0.9804, val accuracy: 0.9803
# Epoch: 491, Train accuracy: 0.9807, val accuracy: 0.9802
# Epoch: 492, Train accuracy: 0.9807, val accuracy: 0.9799
# Epoch: 493, Train accuracy: 0.9807, val accuracy: 0.9805
# Epoch: 494, Train accuracy: 0.9805, val accuracy: 0.9803
# Epoch: 495, Train accuracy: 0.9806, val accuracy: 0.9810
# Epoch: 496, Train accuracy: 0.9809, val accuracy: 0.9810
# Epoch: 497, Train accuracy: 0.9809, val accuracy: 0.9803
# Epoch: 498, Train accuracy: 0.9805, val accuracy: 0.9809
# Epoch: 499, Train accuracy: 0.9809, val accuracy: 0.9806
# Epoch: 500, Train accuracy: 0.9807, val accuracy: 0.9806
# Epoch: 501, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 502, Train accuracy: 0.9808, val accuracy: 0.9806
# Epoch: 503, Train accuracy: 0.9806, val accuracy: 0.9807
# Epoch: 504, Train accuracy: 0.9807, val accuracy: 0.9808
# Epoch: 505, Train accuracy: 0.9809, val accuracy: 0.9806
# Epoch: 506, Train accuracy: 0.9809, val accuracy: 0.9803
# Epoch: 507, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 508, Train accuracy: 0.9806, val accuracy: 0.9809
# Epoch: 509, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 510, Train accuracy: 0.9811, val accuracy: 0.9807
# Epoch: 511, Train accuracy: 0.9807, val accuracy: 0.9808
# Epoch: 512, Train accuracy: 0.9810, val accuracy: 0.9811
# Epoch: 513, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 514, Train accuracy: 0.9808, val accuracy: 0.9810
# Epoch: 515, Train accuracy: 0.9806, val accuracy: 0.9809
# Epoch: 516, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 517, Train accuracy: 0.9809, val accuracy: 0.9803
# Epoch: 518, Train accuracy: 0.9808, val accuracy: 0.9807
# Epoch: 519, Train accuracy: 0.9811, val accuracy: 0.9807
# Epoch: 520, Train accuracy: 0.9810, val accuracy: 0.9811
# Epoch: 521, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 522, Train accuracy: 0.9805, val accuracy: 0.9801
# Epoch: 523, Train accuracy: 0.9806, val accuracy: 0.9807
# Epoch: 524, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 525, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 526, Train accuracy: 0.9807, val accuracy: 0.9800
# Epoch: 527, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 528, Train accuracy: 0.9804, val accuracy: 0.9803
# Epoch: 529, Train accuracy: 0.9807, val accuracy: 0.9807
# Epoch: 530, Train accuracy: 0.9810, val accuracy: 0.9800
# Epoch: 531, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 532, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 533, Train accuracy: 0.9811, val accuracy: 0.9799
# Epoch: 534, Train accuracy: 0.9804, val accuracy: 0.9806
# Epoch: 535, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 536, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 537, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 538, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 539, Train accuracy: 0.9809, val accuracy: 0.9805
# Epoch: 540, Train accuracy: 0.9806, val accuracy: 0.9810
# Epoch: 541, Train accuracy: 0.9808, val accuracy: 0.9810
# Epoch: 542, Train accuracy: 0.9809, val accuracy: 0.9804
# Epoch: 543, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 544, Train accuracy: 0.9810, val accuracy: 0.9805
# Epoch: 545, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 546, Train accuracy: 0.9807, val accuracy: 0.9811
# Epoch: 547, Train accuracy: 0.9808, val accuracy: 0.9803
# Epoch: 548, Train accuracy: 0.9806, val accuracy: 0.9813
# Epoch: 549, Train accuracy: 0.9811, val accuracy: 0.9807
# Epoch: 550, Train accuracy: 0.9807, val accuracy: 0.9810
# Epoch: 551, Train accuracy: 0.9808, val accuracy: 0.9811
# Epoch: 552, Train accuracy: 0.9809, val accuracy: 0.9810
# Epoch: 553, Train accuracy: 0.9809, val accuracy: 0.9810
# Epoch: 554, Train accuracy: 0.9809, val accuracy: 0.9806
# Epoch: 555, Train accuracy: 0.9809, val accuracy: 0.9812
# Epoch: 556, Train accuracy: 0.9813, val accuracy: 0.9813
# Epoch: 557, Train accuracy: 0.9813, val accuracy: 0.9805
# Epoch: 558, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 559, Train accuracy: 0.9808, val accuracy: 0.9807
# Epoch: 560, Train accuracy: 0.9809, val accuracy: 0.9806
# Epoch: 561, Train accuracy: 0.9806, val accuracy: 0.9799
# Epoch: 562, Train accuracy: 0.9806, val accuracy: 0.9808
# Epoch: 563, Train accuracy: 0.9808, val accuracy: 0.9810
# Epoch: 564, Train accuracy: 0.9811, val accuracy: 0.9809
# Epoch: 565, Train accuracy: 0.9811, val accuracy: 0.9809
# Epoch: 566, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 567, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 568, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 569, Train accuracy: 0.9808, val accuracy: 0.9812
# Epoch: 570, Train accuracy: 0.9810, val accuracy: 0.9805
# Epoch: 571, Train accuracy: 0.9811, val accuracy: 0.9805
# Epoch: 572, Train accuracy: 0.9808, val accuracy: 0.9802
# Epoch: 573, Train accuracy: 0.9809, val accuracy: 0.9808
# Epoch: 574, Train accuracy: 0.9812, val accuracy: 0.9806
# Epoch: 575, Train accuracy: 0.9808, val accuracy: 0.9802
# Epoch: 576, Train accuracy: 0.9807, val accuracy: 0.9811
# Epoch: 577, Train accuracy: 0.9810, val accuracy: 0.9812
# Epoch: 578, Train accuracy: 0.9806, val accuracy: 0.9808
# Epoch: 579, Train accuracy: 0.9808, val accuracy: 0.9811
# Epoch: 580, Train accuracy: 0.9802, val accuracy: 0.9804
# Epoch: 581, Train accuracy: 0.9803, val accuracy: 0.9802
# Epoch: 582, Train accuracy: 0.9803, val accuracy: 0.9801
# Epoch: 583, Train accuracy: 0.9804, val accuracy: 0.9808
# Epoch: 584, Train accuracy: 0.9806, val accuracy: 0.9805
# Epoch: 585, Train accuracy: 0.9808, val accuracy: 0.9812
# Epoch: 586, Train accuracy: 0.9807, val accuracy: 0.9812
# Epoch: 587, Train accuracy: 0.9810, val accuracy: 0.9812
# Epoch: 588, Train accuracy: 0.9807, val accuracy: 0.9806
# Epoch: 589, Train accuracy: 0.9802, val accuracy: 0.9808
# Epoch: 590, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 591, Train accuracy: 0.9810, val accuracy: 0.9813
# Epoch: 592, Train accuracy: 0.9809, val accuracy: 0.9806
# Epoch: 593, Train accuracy: 0.9812, val accuracy: 0.9810
# Epoch: 594, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 595, Train accuracy: 0.9811, val accuracy: 0.9808
# Epoch: 596, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 597, Train accuracy: 0.9811, val accuracy: 0.9812
# Epoch: 598, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 599, Train accuracy: 0.9811, val accuracy: 0.9814
# Epoch: 600, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 601, Train accuracy: 0.9809, val accuracy: 0.9809
# Epoch: 602, Train accuracy: 0.9809, val accuracy: 0.9810
# Epoch: 603, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 604, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 605, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 606, Train accuracy: 0.9806, val accuracy: 0.9806
# Epoch: 607, Train accuracy: 0.9806, val accuracy: 0.9811
# Epoch: 608, Train accuracy: 0.9812, val accuracy: 0.9805
# Epoch: 609, Train accuracy: 0.9809, val accuracy: 0.9803
# Epoch: 610, Train accuracy: 0.9806, val accuracy: 0.9804
# Epoch: 611, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 612, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 613, Train accuracy: 0.9808, val accuracy: 0.9812
# Epoch: 614, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 615, Train accuracy: 0.9809, val accuracy: 0.9802
# Epoch: 616, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 617, Train accuracy: 0.9805, val accuracy: 0.9807
# Epoch: 618, Train accuracy: 0.9801, val accuracy: 0.9797
# Epoch: 619, Train accuracy: 0.9800, val accuracy: 0.9798
# Epoch: 620, Train accuracy: 0.9804, val accuracy: 0.9808
# Epoch: 621, Train accuracy: 0.9806, val accuracy: 0.9810
# Epoch: 622, Train accuracy: 0.9810, val accuracy: 0.9804
# Epoch: 623, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 624, Train accuracy: 0.9812, val accuracy: 0.9810
# Epoch: 625, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 626, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 627, Train accuracy: 0.9809, val accuracy: 0.9808
# Epoch: 628, Train accuracy: 0.9811, val accuracy: 0.9806
# Epoch: 629, Train accuracy: 0.9811, val accuracy: 0.9813
# Epoch: 630, Train accuracy: 0.9809, val accuracy: 0.9801
# Epoch: 631, Train accuracy: 0.9810, val accuracy: 0.9803
# Epoch: 632, Train accuracy: 0.9809, val accuracy: 0.9809
# Epoch: 633, Train accuracy: 0.9811, val accuracy: 0.9814
# Epoch: 634, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 635, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 636, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 637, Train accuracy: 0.9815, val accuracy: 0.9812
# Epoch: 638, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 639, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 640, Train accuracy: 0.9809, val accuracy: 0.9812
# Epoch: 641, Train accuracy: 0.9811, val accuracy: 0.9809
# Epoch: 642, Train accuracy: 0.9804, val accuracy: 0.9805
# Epoch: 643, Train accuracy: 0.9809, val accuracy: 0.9812
# Epoch: 644, Train accuracy: 0.9809, val accuracy: 0.9813
# Epoch: 645, Train accuracy: 0.9807, val accuracy: 0.9803
# Epoch: 646, Train accuracy: 0.9808, val accuracy: 0.9812
# Epoch: 647, Train accuracy: 0.9811, val accuracy: 0.9813
# Epoch: 648, Train accuracy: 0.9810, val accuracy: 0.9804
# Epoch: 649, Train accuracy: 0.9803, val accuracy: 0.9813
# Epoch: 650, Train accuracy: 0.9811, val accuracy: 0.9808
# Epoch: 651, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 652, Train accuracy: 0.9813, val accuracy: 0.9811
# Epoch: 653, Train accuracy: 0.9811, val accuracy: 0.9809
# Epoch: 654, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 655, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 656, Train accuracy: 0.9810, val accuracy: 0.9812
# Epoch: 657, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 658, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 659, Train accuracy: 0.9810, val accuracy: 0.9800
# Epoch: 660, Train accuracy: 0.9808, val accuracy: 0.9804
# Epoch: 661, Train accuracy: 0.9810, val accuracy: 0.9806
# Epoch: 662, Train accuracy: 0.9807, val accuracy: 0.9802
# Epoch: 663, Train accuracy: 0.9809, val accuracy: 0.9808
# Epoch: 664, Train accuracy: 0.9807, val accuracy: 0.9810
# Epoch: 665, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 666, Train accuracy: 0.9811, val accuracy: 0.9809
# Epoch: 667, Train accuracy: 0.9811, val accuracy: 0.9814
# Epoch: 668, Train accuracy: 0.9811, val accuracy: 0.9807
# Epoch: 669, Train accuracy: 0.9808, val accuracy: 0.9812
# Epoch: 670, Train accuracy: 0.9805, val accuracy: 0.9809
# Epoch: 671, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 672, Train accuracy: 0.9809, val accuracy: 0.9802
# Epoch: 673, Train accuracy: 0.9805, val accuracy: 0.9808
# Epoch: 674, Train accuracy: 0.9811, val accuracy: 0.9806
# Epoch: 675, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 676, Train accuracy: 0.9813, val accuracy: 0.9811
# Epoch: 677, Train accuracy: 0.9809, val accuracy: 0.9813
# Epoch: 678, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 679, Train accuracy: 0.9809, val accuracy: 0.9809
# Epoch: 680, Train accuracy: 0.9806, val accuracy: 0.9812
# Epoch: 681, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 682, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 683, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 684, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 685, Train accuracy: 0.9809, val accuracy: 0.9809
# Epoch: 686, Train accuracy: 0.9811, val accuracy: 0.9812
# Epoch: 687, Train accuracy: 0.9813, val accuracy: 0.9808
# Epoch: 688, Train accuracy: 0.9805, val accuracy: 0.9799
# Epoch: 689, Train accuracy: 0.9806, val accuracy: 0.9808
# Epoch: 690, Train accuracy: 0.9810, val accuracy: 0.9809
# Epoch: 691, Train accuracy: 0.9812, val accuracy: 0.9814
# Epoch: 692, Train accuracy: 0.9811, val accuracy: 0.9813
# Epoch: 693, Train accuracy: 0.9812, val accuracy: 0.9815
# Epoch: 694, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 695, Train accuracy: 0.9812, val accuracy: 0.9810
# Epoch: 696, Train accuracy: 0.9813, val accuracy: 0.9810
# Epoch: 697, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 698, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 699, Train accuracy: 0.9810, val accuracy: 0.9812
# Epoch: 700, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 701, Train accuracy: 0.9809, val accuracy: 0.9799
# Epoch: 702, Train accuracy: 0.9808, val accuracy: 0.9812
# Epoch: 703, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 704, Train accuracy: 0.9811, val accuracy: 0.9813
# Epoch: 705, Train accuracy: 0.9811, val accuracy: 0.9809
# Epoch: 706, Train accuracy: 0.9812, val accuracy: 0.9802
# Epoch: 707, Train accuracy: 0.9808, val accuracy: 0.9812
# Epoch: 708, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 709, Train accuracy: 0.9810, val accuracy: 0.9812
# Epoch: 710, Train accuracy: 0.9812, val accuracy: 0.9809
# Epoch: 711, Train accuracy: 0.9809, val accuracy: 0.9808
# Epoch: 712, Train accuracy: 0.9807, val accuracy: 0.9814
# Epoch: 713, Train accuracy: 0.9806, val accuracy: 0.9799
# Epoch: 714, Train accuracy: 0.9805, val accuracy: 0.9813
# Epoch: 715, Train accuracy: 0.9808, val accuracy: 0.9815
# Epoch: 716, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 717, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 718, Train accuracy: 0.9813, val accuracy: 0.9815
# Epoch: 719, Train accuracy: 0.9814, val accuracy: 0.9814
# Epoch: 720, Train accuracy: 0.9812, val accuracy: 0.9809
# Epoch: 721, Train accuracy: 0.9809, val accuracy: 0.9796
# Epoch: 722, Train accuracy: 0.9807, val accuracy: 0.9814
# Epoch: 723, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 724, Train accuracy: 0.9808, val accuracy: 0.9795
# Epoch: 725, Train accuracy: 0.9803, val accuracy: 0.9810
# Epoch: 726, Train accuracy: 0.9812, val accuracy: 0.9814
# Epoch: 727, Train accuracy: 0.9807, val accuracy: 0.9811
# Epoch: 728, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 729, Train accuracy: 0.9808, val accuracy: 0.9813
# Epoch: 730, Train accuracy: 0.9811, val accuracy: 0.9814
# Epoch: 731, Train accuracy: 0.9811, val accuracy: 0.9814
# Epoch: 732, Train accuracy: 0.9816, val accuracy: 0.9814
# Epoch: 733, Train accuracy: 0.9812, val accuracy: 0.9804
# Epoch: 734, Train accuracy: 0.9809, val accuracy: 0.9802
# Epoch: 735, Train accuracy: 0.9811, val accuracy: 0.9814
# Epoch: 736, Train accuracy: 0.9812, val accuracy: 0.9808
# Epoch: 737, Train accuracy: 0.9813, val accuracy: 0.9815
# Epoch: 738, Train accuracy: 0.9813, val accuracy: 0.9811
# Epoch: 739, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 740, Train accuracy: 0.9813, val accuracy: 0.9813
# Epoch: 741, Train accuracy: 0.9811, val accuracy: 0.9816
# Epoch: 742, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 743, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 744, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 745, Train accuracy: 0.9810, val accuracy: 0.9811
# Epoch: 746, Train accuracy: 0.9810, val accuracy: 0.9812
# Epoch: 747, Train accuracy: 0.9814, val accuracy: 0.9809
# Epoch: 748, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 749, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 750, Train accuracy: 0.9816, val accuracy: 0.9814
# Epoch: 751, Train accuracy: 0.9813, val accuracy: 0.9813
# Epoch: 752, Train accuracy: 0.9813, val accuracy: 0.9813
# Epoch: 753, Train accuracy: 0.9813, val accuracy: 0.9813
# Epoch: 754, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 755, Train accuracy: 0.9814, val accuracy: 0.9808
# Epoch: 756, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 757, Train accuracy: 0.9815, val accuracy: 0.9813
# Epoch: 758, Train accuracy: 0.9815, val accuracy: 0.9816
# Epoch: 759, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 760, Train accuracy: 0.9810, val accuracy: 0.9811
# Epoch: 761, Train accuracy: 0.9814, val accuracy: 0.9808
# Epoch: 762, Train accuracy: 0.9812, val accuracy: 0.9804
# Epoch: 763, Train accuracy: 0.9810, val accuracy: 0.9813
# Epoch: 764, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 765, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 766, Train accuracy: 0.9809, val accuracy: 0.9813
# Epoch: 767, Train accuracy: 0.9811, val accuracy: 0.9806
# Epoch: 768, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 769, Train accuracy: 0.9810, val accuracy: 0.9808
# Epoch: 770, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 771, Train accuracy: 0.9807, val accuracy: 0.9801
# Epoch: 772, Train accuracy: 0.9807, val accuracy: 0.9815
# Epoch: 773, Train accuracy: 0.9810, val accuracy: 0.9816
# Epoch: 774, Train accuracy: 0.9814, val accuracy: 0.9810
# Epoch: 775, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 776, Train accuracy: 0.9813, val accuracy: 0.9810
# Epoch: 777, Train accuracy: 0.9811, val accuracy: 0.9810
# Epoch: 778, Train accuracy: 0.9810, val accuracy: 0.9811
# Epoch: 779, Train accuracy: 0.9812, val accuracy: 0.9814
# Epoch: 780, Train accuracy: 0.9810, val accuracy: 0.9811
# Epoch: 781, Train accuracy: 0.9812, val accuracy: 0.9815
# Epoch: 782, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 783, Train accuracy: 0.9811, val accuracy: 0.9806
# Epoch: 784, Train accuracy: 0.9809, val accuracy: 0.9813
# Epoch: 785, Train accuracy: 0.9813, val accuracy: 0.9813
# Epoch: 786, Train accuracy: 0.9813, val accuracy: 0.9810
# Epoch: 787, Train accuracy: 0.9810, val accuracy: 0.9813
# Epoch: 788, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 789, Train accuracy: 0.9808, val accuracy: 0.9800
# Epoch: 790, Train accuracy: 0.9800, val accuracy: 0.9801
# Epoch: 791, Train accuracy: 0.9809, val accuracy: 0.9807
# Epoch: 792, Train accuracy: 0.9810, val accuracy: 0.9814
# Epoch: 793, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 794, Train accuracy: 0.9817, val accuracy: 0.9810
# Epoch: 795, Train accuracy: 0.9816, val accuracy: 0.9814
# Epoch: 796, Train accuracy: 0.9815, val accuracy: 0.9813
# Epoch: 797, Train accuracy: 0.9814, val accuracy: 0.9810
# Epoch: 798, Train accuracy: 0.9812, val accuracy: 0.9814
# Epoch: 799, Train accuracy: 0.9810, val accuracy: 0.9811
# Epoch: 800, Train accuracy: 0.9813, val accuracy: 0.9807
# Epoch: 801, Train accuracy: 0.9812, val accuracy: 0.9816
# Epoch: 802, Train accuracy: 0.9814, val accuracy: 0.9814
# Epoch: 803, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 804, Train accuracy: 0.9816, val accuracy: 0.9811
# Epoch: 805, Train accuracy: 0.9818, val accuracy: 0.9814
# Epoch: 806, Train accuracy: 0.9810, val accuracy: 0.9812
# Epoch: 807, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 808, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 809, Train accuracy: 0.9807, val accuracy: 0.9812
# Epoch: 810, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 811, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 812, Train accuracy: 0.9808, val accuracy: 0.9806
# Epoch: 813, Train accuracy: 0.9807, val accuracy: 0.9812
# Epoch: 814, Train accuracy: 0.9810, val accuracy: 0.9813
# Epoch: 815, Train accuracy: 0.9814, val accuracy: 0.9806
# Epoch: 816, Train accuracy: 0.9809, val accuracy: 0.9812
# Epoch: 817, Train accuracy: 0.9814, val accuracy: 0.9812
# Epoch: 818, Train accuracy: 0.9817, val accuracy: 0.9807
# Epoch: 819, Train accuracy: 0.9815, val accuracy: 0.9812
# Epoch: 820, Train accuracy: 0.9813, val accuracy: 0.9808
# Epoch: 821, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 822, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 823, Train accuracy: 0.9814, val accuracy: 0.9816
# Epoch: 824, Train accuracy: 0.9814, val accuracy: 0.9815
# Epoch: 825, Train accuracy: 0.9813, val accuracy: 0.9814
# Epoch: 826, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 827, Train accuracy: 0.9813, val accuracy: 0.9814
# Epoch: 828, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 829, Train accuracy: 0.9813, val accuracy: 0.9809
# Epoch: 830, Train accuracy: 0.9809, val accuracy: 0.9808
# Epoch: 831, Train accuracy: 0.9807, val accuracy: 0.9804
# Epoch: 832, Train accuracy: 0.9811, val accuracy: 0.9812
# Epoch: 833, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 834, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 835, Train accuracy: 0.9810, val accuracy: 0.9808
# Epoch: 836, Train accuracy: 0.9812, val accuracy: 0.9810
# Epoch: 837, Train accuracy: 0.9813, val accuracy: 0.9801
# Epoch: 838, Train accuracy: 0.9809, val accuracy: 0.9812
# Epoch: 839, Train accuracy: 0.9812, val accuracy: 0.9816
# Epoch: 840, Train accuracy: 0.9814, val accuracy: 0.9815
# Epoch: 841, Train accuracy: 0.9814, val accuracy: 0.9812
# Epoch: 842, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 843, Train accuracy: 0.9815, val accuracy: 0.9805
# Epoch: 844, Train accuracy: 0.9811, val accuracy: 0.9814
# Epoch: 845, Train accuracy: 0.9811, val accuracy: 0.9805
# Epoch: 846, Train accuracy: 0.9808, val accuracy: 0.9807
# Epoch: 847, Train accuracy: 0.9809, val accuracy: 0.9814
# Epoch: 848, Train accuracy: 0.9810, val accuracy: 0.9814
# Epoch: 849, Train accuracy: 0.9810, val accuracy: 0.9807
# Epoch: 850, Train accuracy: 0.9812, val accuracy: 0.9808
# Epoch: 851, Train accuracy: 0.9811, val accuracy: 0.9813
# Epoch: 852, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 853, Train accuracy: 0.9814, val accuracy: 0.9812
# Epoch: 854, Train accuracy: 0.9816, val accuracy: 0.9812
# Epoch: 855, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 856, Train accuracy: 0.9816, val accuracy: 0.9811
# Epoch: 857, Train accuracy: 0.9816, val accuracy: 0.9815
# Epoch: 858, Train accuracy: 0.9812, val accuracy: 0.9810
# Epoch: 859, Train accuracy: 0.9810, val accuracy: 0.9810
# Epoch: 860, Train accuracy: 0.9814, val accuracy: 0.9816
# Epoch: 861, Train accuracy: 0.9814, val accuracy: 0.9816
# Epoch: 862, Train accuracy: 0.9816, val accuracy: 0.9811
# Epoch: 863, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 864, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 865, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 866, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 867, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 868, Train accuracy: 0.9815, val accuracy: 0.9815
# Epoch: 869, Train accuracy: 0.9813, val accuracy: 0.9817
# Epoch: 870, Train accuracy: 0.9814, val accuracy: 0.9812
# Epoch: 871, Train accuracy: 0.9813, val accuracy: 0.9804
# Epoch: 872, Train accuracy: 0.9808, val accuracy: 0.9808
# Epoch: 873, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 874, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 875, Train accuracy: 0.9813, val accuracy: 0.9810
# Epoch: 876, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 877, Train accuracy: 0.9815, val accuracy: 0.9812
# Epoch: 878, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 879, Train accuracy: 0.9816, val accuracy: 0.9815
# Epoch: 880, Train accuracy: 0.9816, val accuracy: 0.9816
# Epoch: 881, Train accuracy: 0.9814, val accuracy: 0.9816
# Epoch: 882, Train accuracy: 0.9817, val accuracy: 0.9807
# Epoch: 883, Train accuracy: 0.9813, val accuracy: 0.9816
# Epoch: 884, Train accuracy: 0.9815, val accuracy: 0.9816
# Epoch: 885, Train accuracy: 0.9815, val accuracy: 0.9813
# Epoch: 886, Train accuracy: 0.9814, val accuracy: 0.9814
# Epoch: 887, Train accuracy: 0.9813, val accuracy: 0.9816
# Epoch: 888, Train accuracy: 0.9809, val accuracy: 0.9810
# Epoch: 889, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 890, Train accuracy: 0.9814, val accuracy: 0.9814
# Epoch: 891, Train accuracy: 0.9816, val accuracy: 0.9816
# Epoch: 892, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 893, Train accuracy: 0.9810, val accuracy: 0.9813
# Epoch: 894, Train accuracy: 0.9810, val accuracy: 0.9813
# Epoch: 895, Train accuracy: 0.9813, val accuracy: 0.9811
# Epoch: 896, Train accuracy: 0.9815, val accuracy: 0.9813
# Epoch: 897, Train accuracy: 0.9816, val accuracy: 0.9809
# Epoch: 898, Train accuracy: 0.9817, val accuracy: 0.9810
# Epoch: 899, Train accuracy: 0.9812, val accuracy: 0.9808
# Epoch: 900, Train accuracy: 0.9807, val accuracy: 0.9807
# Epoch: 901, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 902, Train accuracy: 0.9815, val accuracy: 0.9817
# Epoch: 903, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 904, Train accuracy: 0.9815, val accuracy: 0.9815
# Epoch: 905, Train accuracy: 0.9812, val accuracy: 0.9808
# Epoch: 906, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 907, Train accuracy: 0.9816, val accuracy: 0.9816
# Epoch: 908, Train accuracy: 0.9816, val accuracy: 0.9813
# Epoch: 909, Train accuracy: 0.9814, val accuracy: 0.9815
# Epoch: 910, Train accuracy: 0.9816, val accuracy: 0.9812
# Epoch: 911, Train accuracy: 0.9817, val accuracy: 0.9814
# Epoch: 912, Train accuracy: 0.9814, val accuracy: 0.9808
# Epoch: 913, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 914, Train accuracy: 0.9814, val accuracy: 0.9815
# Epoch: 915, Train accuracy: 0.9816, val accuracy: 0.9813
# Epoch: 916, Train accuracy: 0.9813, val accuracy: 0.9815
# Epoch: 917, Train accuracy: 0.9815, val accuracy: 0.9810
# Epoch: 918, Train accuracy: 0.9815, val accuracy: 0.9817
# Epoch: 919, Train accuracy: 0.9816, val accuracy: 0.9803
# Epoch: 920, Train accuracy: 0.9808, val accuracy: 0.9816
# Epoch: 921, Train accuracy: 0.9814, val accuracy: 0.9811
# Epoch: 922, Train accuracy: 0.9813, val accuracy: 0.9816
# Epoch: 923, Train accuracy: 0.9815, val accuracy: 0.9815
# Epoch: 924, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 925, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 926, Train accuracy: 0.9813, val accuracy: 0.9815
# Epoch: 927, Train accuracy: 0.9813, val accuracy: 0.9814
# Epoch: 928, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 929, Train accuracy: 0.9813, val accuracy: 0.9804
# Epoch: 930, Train accuracy: 0.9808, val accuracy: 0.9809
# Epoch: 931, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 932, Train accuracy: 0.9815, val accuracy: 0.9818
# Epoch: 933, Train accuracy: 0.9814, val accuracy: 0.9816
# Epoch: 934, Train accuracy: 0.9810, val accuracy: 0.9814
# Epoch: 935, Train accuracy: 0.9815, val accuracy: 0.9816
# Epoch: 936, Train accuracy: 0.9815, val accuracy: 0.9804
# Epoch: 937, Train accuracy: 0.9812, val accuracy: 0.9812
# Epoch: 938, Train accuracy: 0.9811, val accuracy: 0.9816
# Epoch: 939, Train accuracy: 0.9812, val accuracy: 0.9811
# Epoch: 940, Train accuracy: 0.9815, val accuracy: 0.9811
# Epoch: 941, Train accuracy: 0.9816, val accuracy: 0.9816
# Epoch: 942, Train accuracy: 0.9815, val accuracy: 0.9812
# Epoch: 943, Train accuracy: 0.9811, val accuracy: 0.9812
# Epoch: 944, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 945, Train accuracy: 0.9813, val accuracy: 0.9806
# Epoch: 946, Train accuracy: 0.9815, val accuracy: 0.9811
# Epoch: 947, Train accuracy: 0.9817, val accuracy: 0.9812
# Epoch: 948, Train accuracy: 0.9814, val accuracy: 0.9816
# Epoch: 949, Train accuracy: 0.9813, val accuracy: 0.9812
# Epoch: 950, Train accuracy: 0.9816, val accuracy: 0.9816
# Epoch: 951, Train accuracy: 0.9815, val accuracy: 0.9812
# Epoch: 952, Train accuracy: 0.9815, val accuracy: 0.9817
# Epoch: 953, Train accuracy: 0.9816, val accuracy: 0.9817
# Epoch: 954, Train accuracy: 0.9814, val accuracy: 0.9815
# Epoch: 955, Train accuracy: 0.9811, val accuracy: 0.9815
# Epoch: 956, Train accuracy: 0.9809, val accuracy: 0.9813
# Epoch: 957, Train accuracy: 0.9809, val accuracy: 0.9811
# Epoch: 958, Train accuracy: 0.9812, val accuracy: 0.9814
# Epoch: 959, Train accuracy: 0.9813, val accuracy: 0.9815
# Epoch: 960, Train accuracy: 0.9813, val accuracy: 0.9815
# Epoch: 961, Train accuracy: 0.9811, val accuracy: 0.9813
# Epoch: 962, Train accuracy: 0.9812, val accuracy: 0.9813
# Epoch: 963, Train accuracy: 0.9809, val accuracy: 0.9812
# Epoch: 964, Train accuracy: 0.9816, val accuracy: 0.9816
# Epoch: 965, Train accuracy: 0.9818, val accuracy: 0.9816
# Epoch: 966, Train accuracy: 0.9815, val accuracy: 0.9808
# Epoch: 967, Train accuracy: 0.9809, val accuracy: 0.9802
# Epoch: 968, Train accuracy: 0.9812, val accuracy: 0.9818
# Epoch: 969, Train accuracy: 0.9816, val accuracy: 0.9811
# Epoch: 970, Train accuracy: 0.9815, val accuracy: 0.9817
# Epoch: 971, Train accuracy: 0.9813, val accuracy: 0.9808
# Epoch: 972, Train accuracy: 0.9811, val accuracy: 0.9811
# Epoch: 973, Train accuracy: 0.9815, val accuracy: 0.9813
# Epoch: 974, Train accuracy: 0.9813, val accuracy: 0.9811
# Epoch: 975, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 976, Train accuracy: 0.9814, val accuracy: 0.9813
# Epoch: 977, Train accuracy: 0.9815, val accuracy: 0.9803
# Epoch: 978, Train accuracy: 0.9812, val accuracy: 0.9814
# Epoch: 979, Train accuracy: 0.9812, val accuracy: 0.9810
# Epoch: 980, Train accuracy: 0.9814, val accuracy: 0.9814
# Epoch: 981, Train accuracy: 0.9815, val accuracy: 0.9813
# Epoch: 982, Train accuracy: 0.9817, val accuracy: 0.9816
# Epoch: 983, Train accuracy: 0.9816, val accuracy: 0.9813
# Epoch: 984, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 985, Train accuracy: 0.9815, val accuracy: 0.9814
# Epoch: 986, Train accuracy: 0.9815, val accuracy: 0.9812
# Epoch: 987, Train accuracy: 0.9813, val accuracy: 0.9816
# Epoch: 988, Train accuracy: 0.9815, val accuracy: 0.9812
# Epoch: 989, Train accuracy: 0.9816, val accuracy: 0.9813
# Epoch: 990, Train accuracy: 0.9814, val accuracy: 0.9812
# Epoch: 991, Train accuracy: 0.9812, val accuracy: 0.9809
# Epoch: 992, Train accuracy: 0.9813, val accuracy: 0.9811
# Epoch: 993, Train accuracy: 0.9809, val accuracy: 0.9813
# Epoch: 994, Train accuracy: 0.9814, val accuracy: 0.9817
# Epoch: 995, Train accuracy: 0.9815, val accuracy: 0.9811
# Epoch: 996, Train accuracy: 0.9812, val accuracy: 0.9807
# Epoch: 997, Train accuracy: 0.9811, val accuracy: 0.9813
# Epoch: 998, Train accuracy: 0.9815, val accuracy: 0.9811
# Epoch: 999, Train accuracy: 0.9816, val accuracy: 0.9811
# Epoch: 1000, Train accuracy: 0.9814, val accuracy: 0.9813
# CPU times: user 6min 31s, sys: 2min 10s, total: 8min 41s
# Wall time: 8min 45s

# %%
fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(10, 5))
axs[0].plot(np.arange(len(t_loss_v)), t_loss_v, label="training")
axs[0].plot(np.arange(len(v_loss_v)), v_loss_v, label="validation")
axs[0].set_title("Training and validation loss")
axs[0].set_yscale("log")
axs[0].legend()
axs[1].plot(np.arange(len(t_acc_v)), t_acc_v, label="training")
axs[1].plot(np.arange(len(v_acc_v)), v_acc_v, label="validation")
axs[1].set_title("Training and validation accuracy")
axs[1].set_yscale("linear")
axs[1].legend()
axs[1].set_ylim([0.92, np.max(t_acc_v)+0.001])
# Out:
# (0.92, 0.9827784618439998)

# %% [markdown]
# ### Did it work?

# %% [markdown]
# Running the above with 1 graph iteration gives me about 90% accuracy in 200 epochs.

# %% [markdown]
# The best performance that I can get with some simple manual tuning is around 98% accuracy (for max_angle = 6/6*np.pi). We can improve the efficiency at the cost of purity by raising the weight on true edges, but the accuracy won't significantly improve. In general, the biggest changes were from increasing the width (i.e. the number of dimensions) of the hidden layers. We can visualise the performance on a particular graph, colouring true positives black, false positives red, true negatives a transparent black, and false negatives in blue.

# %%
def plot_toy_classified(event, preds, cut=0.5):
    
    plt.figure(figsize=(10,5))
    x, y = event.x[:,0].numpy(), event.x[:,1].numpy()
    edges = event.edge_index.numpy()
    labels = event.y
    plt.scatter(x, y, c='k')
    
    preds = preds.detach().numpy()
    
    for j in range(len(labels)):
        
        # False negatives
        if preds[j] < cut and labels[j].item() > cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '--', c='b')

        # False positives
        if preds[j] > cut and labels[j].item() < cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='r', alpha=preds[j])

        # True positives
        if preds[j] > cut and labels[j].item() > cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='k', alpha=preds[j])
                
        # True negatives
        if preds[j] < cut and labels[j].item() < cut:
            plt.plot([x[edges[0,j]], x[edges[1,j]]],
                     [y[edges[0,j]], y[edges[1,j]]],
                     '-', c='k', alpha=preds[j])

# %%
for i in range(5):
    data = test_loader.dataset[i].to(device)
    preds = torch.sigmoid(model(data)).to('cpu')
    plot_toy_classified(data.to('cpu'), preds, cut = 0.6)

# %% [markdown]
# So we can see that it's working quite well. Few missed true edges, and few misclassified fake edges. The ratio of false positives to false negatives (which can be defined with efficiency and purity) is controlled by the cut we put on the prediction score.

# %% [markdown]
# ### Plot the confussion matrix (for edges)

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import RocCurveDisplay, roc_curve
from sklearn.metrics import PrecisionRecallDisplay, precision_recall_curve

y_test = torch.cat([data.y.cpu() for data in test_loader.dataset])
y_pred = torch.cat([torch.sigmoid(model(data.to(device))) > 0.6 for data in test_loader.dataset]).cpu()

ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot()

# %% [markdown]
# # **That's all**
